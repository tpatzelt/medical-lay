# %%
import jsonlines
from src.data_loading import annotations as tlc_annotations, load_tlc_samples
from src.models import Sample
from config import TLCPaths
from typing import Tuple
import json
import csv
from dataclasses import dataclass, asdict

from spacy.lang.de import German # updated
from src.preprocessing import cistem

# %%
with open(TLCPaths.project_data_path.joinpath("search_terms_single_and_ids.json")) as fp:
    search_terms = json.load(fp)
search_terms
# Out:
# {'flatulenz': [6992,
#   7046,
#   6316,
#   5453,
#   6328,
#   6569,
#   6959,
#   5926,
#   4901,
#   5166,
#   6076,
#   4911,
#   7389,
#   6383,
#   6121,
#   1308,
#   6537,
#   4654,
#   4836,
#   5055,
#   5391,
#   6028,
#   7176,
#   5651,
#   4754,
#   5770,
#   6962,
#   6964,
#   6358,
#   5291,
#   5296,
#   4850,
#   4994,
#   5812,
#   4738,
#   6190,
#   6955,
#   6957,
#   4758,
#   7097,
#   5630,
#   5691,
#   5692,
#   5693,
#   7309,
#   5117,
#   6932,
#   4838,
#   4840,
#   6584,
#   5121,
#   5904,
#   4887,
#   6747,
#   6749,
#   4606,
#   4931,
#   6504,
#   4650,
#   4651,
#   7026,
#   7064,
#   5837,
#   5967,
#   5030,
#   7245,
#   7333,
#   6034,
#   7149,
#   6484,
#   6712,
#   5218,
#   5849],
#  'pankrea': [6993,
#   4638,
#   7357,
#   7388,
#   4929,
#   6097,
#   1491,
#   5767,
#   4613,
#   3031,
#   6819,
#   5287,
#   5046,
#   5047,
#   6566,
#   584,
#   6432,
#   313,
#   314,
#   4950,
#   4755,
#   4793,
#   4794,
#   4798,
#   5081,
#   4857,
#   7376,
#   5101,
#   4728,
#   5979,
#   6813,
#   5048,
#   5052,
#   6774,
#   4748],
#  'pyelonephriti': [3633,
#   221,
#   718,
#   2639,
#   185,
#   3311,
#   3312,
#   4582,
#   671,
#   3691,
#   841,
#   168,
#   165,
#   923,
#   2771,
#   3001,
#   2743,
#   344,
#   170,
#   171,
#   4074,
#   4098,
#   2029,
#   1415,
#   1416,
#   1417,
#   3456,
#   1969,
#   1771,
#   1772,
#   1773,
#   1774,
#   1775,
#   2331,
#   1573,
#   1574,
#   1619,
#   1620,
#   2227,
#   2228,
#   2829,
#   2197,
#   2832,
#   834,
#   393,
#   844,
#   3232,
#   958,
#   4056,
#   4057,
#   3560,
#   3561,
#   3524,
#   3525,
#   2239,
#   2240,
#   2906,
#   2910,
#   2911,
#   2912,
#   1739,
#   1740,
#   1743,
#   2866,
#   2470,
#   3516,
#   4183,
#   3767,
#   3755,
#   3759,
#   3760,
#   3599,
#   3600,
#   1464,
#   2079,
#   2080,
#   3476,
#   2543,
#   213,
#   981,
#   9,
#   4528,
#   4030,
#   4031,
#   565,
#   1207,
#   4052,
#   559,
#   1414,
#   1160,
#   4172,
#   3912,
#   3914,
#   1570,
#   1651,
#   1175,
#   595,
#   3567,
#   3569,
#   3570,
#   2653,
#   1359,
#   1360,
#   1365,
#   605,
#   297,
#   4196,
#   4198,
#   4199,
#   2640,
#   2641,
#   3772,
#   1466,
#   2806,
#   1334,
#   3020,
#   123,
#   2903,
#   4419,
#   570],
#  'urethra': [843,
#   2780,
#   3724,
#   2293,
#   983,
#   3535,
#   1467,
#   3489,
#   1325,
#   3072,
#   1166,
#   375,
#   2937,
#   1291,
#   3158,
#   2631,
#   2165,
#   1006],
#  'гастритис': [6277],
#  'nephropto': [975,
#   1082,
#   1834,
#   4277,
#   591,
#   2868,
#   3379,
#   1205,
#   1206,
#   3952,
#   3953,
#   1569,
#   3042,
#   2951,
#   1567,
#   1274,
#   1428,
#   130,
#   1171,
#   1587,
#   749,
#   4475,
#   4477,
#   4479,
#   622,
#   2953,
#   887,
#   1589,
#   840,
#   956,
#   2392],
#  'nebennierenadenom': [2894, 4072],
#  'defakatio': [7003,
#   7004,
#   7006,
#   7007,
#   6562,
#   6563,
#   7160,
#   6669,
#   7285,
#   6512,
#   6513,
#   6514,
#   5619,
#   5775,
#   6934,
#   5718,
#   5719,
#   5720,
#   6015,
#   6148,
#   5623,
#   5624,
#   6680,
#   5834],
#  'kot': [7005, 7008, 6582],
#  'nabelhernie': [5462],
#  'partielle kolektomie': [5463, 3347],
#  'lacto': [5826, 6040, 5817],
#  'extrasystol': [5827, 5556, 7095, 5380],
#  'inkarzeratio': [5652,
#   6688,
#   6492,
#   5196,
#   5563,
#   5017,
#   5330,
#   6388,
#   5037,
#   4596,
#   4855,
#   4985,
#   6987,
#   5075],
#  'adhasio': [5653, 5654, 5334, 6386, 6387, 5038, 5040, 5335, 114, 3848],
#  'ileu': [5655,
#   6689,
#   6493,
#   6155,
#   6156,
#   5197,
#   5229,
#   4999,
#   5711,
#   5564,
#   5018,
#   7136,
#   5331,
#   6389,
#   5036,
#   5039,
#   4597,
#   4856,
#   6651,
#   4986,
#   5989,
#   5828,
#   5076,
#   4984,
#   4812,
#   4813,
#   6988],
#  'endorkinolog': [3122],
#  'morbus addiso': [3123],
#  'allgemeinanasthesie': [5323],
#  'darmkolik': [5324],
#  'wehenartige schmerz': [5325, 1280],
#  'ileostoma': [6401, 6334, 5348, 5349, 5351, 5353],
#  'menstruatio': [4577, 1440, 1422, 4226, 401, 406, 884],
#  'monatsblutung': [4578, 1442, 1423, 403, 404],
#  'diabet': [3012,
#   3013,
#   3014,
#   3015,
#   1668,
#   1669,
#   4157,
#   4158,
#   4296,
#   4297,
#   2395,
#   2396,
#   3138,
#   3139,
#   3808,
#   2155,
#   2156,
#   56,
#   57,
#   1793,
#   2834],
#  'polyurie': [3016,
#   2440,
#   371,
#   764,
#   776,
#   1368,
#   497,
#   503,
#   3325,
#   3326,
#   3327,
#   708,
#   3809,
#   91,
#   102,
#   1132,
#   2244,
#   2245,
#   2247,
#   854,
#   21,
#   3233,
#   1867,
#   4194,
#   3273,
#   1795,
#   1796],
#  'diarrho': [5746,
#   5748,
#   5749,
#   5751,
#   6602,
#   5416,
#   5419,
#   5109,
#   5535,
#   6611,
#   6612,
#   6613,
#   6614,
#   6615,
#   6315,
#   4734,
#   4736,
#   6743,
#   6329,
#   6053,
#   5898,
#   5236,
#   5238,
#   391,
#   3385,
#   6136,
#   1971,
#   2992,
#   3938,
#   3676,
#   4397,
#   1432,
#   1734,
#   3598,
#   4445,
#   125,
#   7181,
#   4240,
#   2986,
#   3882,
#   3281,
#   2075,
#   2665,
#   454,
#   963,
#   803,
#   2179,
#   3249,
#   2271,
#   4264,
#   867,
#   411,
#   2901,
#   4028,
#   822,
#   823,
#   3237,
#   3315,
#   389,
#   3998,
#   1803,
#   1711,
#   3018,
#   2,
#   290,
#   3530,
#   296,
#   6341,
#   277,
#   1855],
#  'niereninsuffizienz': [3244,
#   3555,
#   2167,
#   2170,
#   704,
#   737,
#   2847,
#   1858,
#   3133,
#   3041,
#   1738,
#   635,
#   1663,
#   1631,
#   1244,
#   1247,
#   1249,
#   1782,
#   1472,
#   3128,
#   4424,
#   2429],
#  'nephrolog': [3245,
#   2171,
#   3942,
#   3949,
#   3812,
#   2805,
#   900,
#   2584,
#   2586,
#   1226,
#   1980,
#   4279,
#   1937,
#   4266,
#   2152,
#   280,
#   1557,
#   435,
#   722,
#   2417,
#   4420,
#   1822,
#   2893,
#   3154,
#   1955,
#   2297],
#  'wasserharnruhr': [166, 1753, 676, 1328],
#  'mammakarzinom': [3059,
#   3459,
#   3460,
#   1343,
#   1321,
#   145,
#   839,
#   1626,
#   4339,
#   2870,
#   3800,
#   4514,
#   1471,
#   2264,
#   469,
#   3246,
#   1516],
#  'leukozyt': [1437,
#   6784,
#   1693,
#   5214,
#   4197,
#   2957,
#   3626,
#   4795,
#   5581,
#   178,
#   3471,
#   1004,
#   638],
#  'regelblutung': [1441, 1424, 4225, 402, 405],
#  'leukozyturie': [1443, 3605, 1617],
#  'dialy': [804,
#   805,
#   806,
#   807,
#   809,
#   810,
#   812,
#   813,
#   4312,
#   4313,
#   1221,
#   1222,
#   1666,
#   1667,
#   1670,
#   1671,
#   1672,
#   1673,
#   4228,
#   4229,
#   4233,
#   4234,
#   4499,
#   4500,
#   4501,
#   4502,
#   4503,
#   4504,
#   4153,
#   4154,
#   4162,
#   4163,
#   4165,
#   4166,
#   4375,
#   4376,
#   4377,
#   4378,
#   4381,
#   4382,
#   4383,
#   4384,
#   4386,
#   4387,
#   4388,
#   4389,
#   4392,
#   4394,
#   4429,
#   4430,
#   1478,
#   1479,
#   1480,
#   1481,
#   1482,
#   1483,
#   1484,
#   1485,
#   1486,
#   1487,
#   301,
#   302,
#   4509,
#   1902,
#   1903,
#   2316,
#   4459,
#   4460,
#   4461,
#   4462,
#   4463,
#   4464,
#   927,
#   928,
#   1137,
#   1138,
#   1139,
#   1140,
#   1141,
#   1143,
#   1144,
#   1145,
#   1146,
#   1147,
#   4073,
#   4481,
#   4482,
#   4484,
#   4485,
#   4487,
#   4489,
#   4491,
#   4492,
#   1228,
#   1229,
#   1230,
#   1232,
#   1233,
#   1235,
#   2373,
#   2374,
#   3481,
#   3482,
#   614,
#   615,
#   4268,
#   4272,
#   4273,
#   4447,
#   4449,
#   4454,
#   4455,
#   4456,
#   4457,
#   2393,
#   2394,
#   2399,
#   2400,
#   2403,
#   2404,
#   2405,
#   2406,
#   2811,
#   2812,
#   2611,
#   2612,
#   968,
#   3140,
#   3141,
#   3142,
#   3143,
#   2889,
#   2890,
#   521,
#   522,
#   523,
#   524,
#   525,
#   526,
#   527,
#   528,
#   529,
#   530,
#   531,
#   532,
#   533,
#   534,
#
#   4732,
#   6578,
#   5366,
#   5275,
#   4602,
#   4591,
#   6994,
#   6995,
#   7191,
#   6014,
#   4610,
#   6978,
#   7351,
#   5552,
#   2226,
#   7328,
#   4723,
#   4724,
#   5797,
#   6755,
#   7216,
#   1469],
#  'anamie': [1947,
#   1396,
#   1399,
#   1400,
#   5914,
#   2588,
#   2589,
#   5340,
#   1047,
#   1048,
#   1049,
#   1050,
#   2690,
#   2691,
#   2692,
#   4097,
#   3876,
#   1121,
#   1122,
#   1123,
#   353,
#   354,
#   1638,
#   1639,
#   1640,
#   1641,
#   1642,
#   1643,
#   943,
#   944,
#   945,
#   947,
#   949,
#   950,
#   951,
#   952,
#   2924,
#   2925,
#   2928,
#   1100,
#   1101,
#   1102,
#   1103,
#   1104,
#   1105,
#   1111,
#   1112,
#   1113,
#   1114,
#   1115,
#   1116,
#   1117,
#   1118,
#   946],
#  'nephrotoxizitat': [1949],
#  'thyreoiditi': [1951, 6849],
#  'abdominalkrampf': [5418, 5819, 1801],
#  'pelvi': [5420, 2699],
#  'dolor': [5421,
#   2322,
#   2325,
#   2328,
#   689,
#   1425,
#   546,
#   3290,
#   4017,
#   6853,
#   505,
#   511,
#   5724,
#   1075,
#   1076,
#   1077,
#   5813,
#   2997,
#   4759,
#   5628,
#   916,
#   22,
#   1852,
#   7016,
#   5188,
#   3844,
#   3846,
#   5097,
#   5099],
#  'algesie': [5422,
#   2323,
#   2326,
#   2329,
#   691,
#   1426,
#   547,
#   3291,
#   4016,
#   6854,
#   506,
#   512,
#   5725,
#   1078,
#   1079,
#   1080,
#   5814,
#   2998,
#   4760,
#   5629,
#   917,
#   23,
#   1853,
#   7015,
#   5189,
#   3845,
#   3847,
#   5098,
#   5100],
#  'myogelo': [5423, 3930, 4045, 4048, 4051, 3571, 5924, 4744],
#  'steno': [6337, 3414, 4831, 7122, 2563, 82, 86, 98, 112],
#  'gallenkolik': [2534],
#  'obstipier': [5110, 5245, 6049, 5072],
#  'magenlahmung': [6254, 5457, 5758, 4948],
#  'diaphor': [6255, 5449, 874, 4507, 2133],
#  'transpiratio': [6256, 5450, 873, 5284, 4508, 2132],
#  'hyperlipasamie': [6257,
#   6260,
#   5447,
#   5533,
#   5980,
#   7320,
#   6026,
#   6811,
#   5074,
#   5760,
#   7034,
#   4865,
#   6518,
#   4860,
#   5283,
#   5559,
#   4993,
#   4947,
#   6394,
#   6397,
#   6065,
#   5612,
#   5044,
#   5794,
#   7312,
#   6618,
#   6809,
#   4746,
#   6024,
#   4684,
#   7127,
#   5977],
#  'lahmung': [6261, 5458, 5759, 4949],
#  'gastropar': [6262, 5783, 5785, 5787],
#  'hypertonie': [204,
#   3892,
#   3896,
#   3946,
#   4349,
#   3994,
#   2180,
#   2182,
#   4159,
#   3050,
#   2608,
#   1880,
#   1881,
#   1885,
#   430,
#   673,
#   1978,
#   4294,
#   6085,
#   6103,
#   262,
#   1916,
#   5144,
#   5146,
#   2590,
#   1610,
#   2884,
#   1539,
#   1735,
#   660,
#   2694,
#   4257,
#   459,
#   461,
#   964,
#   1625,
#   4261,
#   2721,
#   3869,
#   3873,
#   2368,
#   863,
#   6286,
#   1862,
#   5673,
#   2922,
#   2926,
#   3496,
#   3500,
#   3506,
#   1107,
#   1109,
#   2060,
#   1777,
#   5961,
#   5962,
#   1504,
#   2837,
#   6279,
#   967],
#  'hypertonu': [205,
#   3893,
#   3897,
#   3947,
#   4350,
#   3995,
#   2181,
#   2183,
#   4160,
#   3051,
#   2607,
#   1879,
#   1882,
#   1886,
#   431,
#   674,
#   1979,
#   4295,
#   6086,
#   6104,
#   261,
#   1917,
#   5145,
#   5147,
#   2591,
#   1611,
#   2885,
#   1540,
#   1736,
#   661,
#   2695,
#   4258,
#   460,
#   462,
#   4262,
#   2722,
#   3868,
#   2369,
#   864,
#   1863,
#   5674,
#   2923,
#   2927,
#   3497,
#   3501,
#   3507,
#   1108,
#   1110,
#   2061,
#   1778,
#   5959,
#   5960,
#   1505,
#   2838,
#   6280,
#   3874],
#  'diab': [206, 207],
#  'perfusionsstorung': [208, 4169],
#  'kryokonservier': [209, 1683],
#  'kryokonservierung von sperma': [210],
#  'fertilitat': [211,
#   2785,
#   1718,
#   1678,
#   4168,
#   2609,
#   4466,
#   932,
#   1634,
#   2375,
#   1786,
#   449,
#   3352,
#   2814,
#   4434,
#   2579,
#   2231,
#   890,
#   891,
#   576,
#   1199,
#   1001,
#   1002,
#   1407,
#   1408],
#  'urozystitid': [1267, 686],
#  'ab': [1269, 3055, 771, 3932, 496, 500, 1131, 3739, 3740, 3741],
#  'vaginalflora': [1270, 2202],
#  'homoosta': [1271],
#  'erythrozyt': [1397, 2747, 2752, 1721, 3625, 1528, 1530, 321, 752, 640],
#  'erythropenie': [1398, 328],
#  'doppel-j-kathet': [2711,
#   2715,
#   2717,
#   598,
#   3645,
#   3646,
#   3647,
#   626,
#   627,
#   628,
#   2185,
#   2186,
#   2187,
#   3019],
#  'nephrozirrho': [3087,
#   987,
#   1765,
#   679,
#   2585,
#   4018,
#   4020,
#   2453,
#   2455,
#   2456,
#   2457,
#   2459,
#   2461,
#   2463,
#   3656,
#   2728,
#   1599,
#   1604,
#   1605,
#   3782,
#   3783,
#   3784,
#   3785,
#   3788,
#   4529,
#   4533,
#   3593,
#   3595,
#   268,
#   1864,
#   1865,
#   1866,
#   2030,
#   3250,
#   4193,
#   3114,
#   3115,
#   2298],
#  'kongenital': [3088,
#   986,
#   1769,
#   1904,
#   681,
#   2587,
#   4493,
#   4019,
#   2731,
#   120,
#   4532,
#   3594,
#   1872,
#   2031,
#   4195,
#   601,
#   3116,
#   2299,
#   2464,
#   3658,
#   1603,
#   3787],
#  'postoperativ': [3090],
#  'pyelon ': [4241, 3328, 4217, 2386, 2027, 2028, 643],
#  'osophagiti': [5231,
#   6738,
#   5838,
#   5927,
#   4930,
#   6706,
#   6707,
#   5134,
#   5923,
#   5925,
#   5415,
#   6564,
#   6565,
#   4141,
#   5356,
#   5372,
#   5373,
#   7377,
#   7256,
#   4941,
#   6860,
#   6678,
#   7028,
#   6804,
#   5183,
#   5804,
#   7228,
#   5631,
#   5260,
#   6927,
#   6303,
#   7156,
#   6405,
#   7220],
#  'urea': [4010,
#   878,
#   3461,
#   4069,
#   2598,
#   2193,
#   1707,
#   433,
#   731,
#   733,
#   734,
#   2750,
#   2963,
#   1609,
#   3660,
#   3980,
#   3982,
#   3342,
#   2215,
#   2663,
#   998,
#   2265,
#   480,
#   140,
#   1510,
#   1517],
#  'hypokalzamie': [3550],
#  'hyperphosphatamie': [3551, 3552],
#  'osteoporo': [3554],
#  'letal': [6272, 2173, 6497, 2738],
#  'pyrosi': [6742, 6119],
#  'protei': [639,
#   1646,
#   2206,
#   2208,
#   1345,
#   3108,
#   2737,
#   1816,
#   1706,
#   1709,
#   745,
#   3588,
#   3467,
#   2748,
#   2091,
#   3744,
#   3745,
#   3747,
#   3748,
#   1956,
#   2546,
#   1689,
#   1691,
#   441,
#   444,
#   445,
#   1572,
#   1936,
#   2655,
#   2656,
#   2657,
#   1627,
#   5059,
#   965,
#   1614,
#   3871,
#   3872,
#   3875,
#   2157,
#   179,
#   2854,
#   2266,
#   351,
#   352,
#   231,
#   1714,
#   470,
#   1097,
#   2876,
#   2877,
#   174,
#   1458,
#   4191,
#   1684,
#   420,
#   2836,
#   1005,
#   442,
#   398],
#  'tachykardie': [5635,
#   4291,
#   2286,
#   2362,
#   2364,
#   5016,
#   680,
#   6087,
#   6091,
#   6102,
#   6125,
#   6135,
#   6175,
#   6901,
#   3613,
#   2720,
#   7094,
#   1868,
#   5375,
#   2432,
#   2434,
#   2436,
#   2437,
#   1503,
#   5177,
#   4471,
#   3927],
#  'reflux': [5637,
#   5638,
#   5639,
#   5640,
#   5001,
#   6082,
#   6006,
#   6208,
#   6209,
#   5791,
#   5792,
#   4924,
#   3445,
#   5224,
#   5273,
#   4373,
#   6182,
#   6197,
#   6201,
#   6032,
#   4133,
#   7101,
#   7102,
#   5676,
#   5803,
#   6442,
#   5946,
#   5947,
#   5948,
#   5264,
#   5127,
#   5130,
#   6083],
#  'pharynx': [5643, 5360],
#  'sinusiti': [5644, 6373, 1548],
#  'tonsilliti': [5645, 4679, 6933, 4586, 7247, 3733, 3734],
#  'dysphonie': [5646],
#  'analgetikum': [5647, 1830, 1831, 3293],
#  'analgetika': [2324,
#   2327,
#   2330,
#   6466,
#   1017,
#   1832,
#   8,
#   3292,
#   2516,
#   2572,
#   3682,
#   1297,
#   1298,
#   4025,
#   4026,
#   2217,
#   3667,
#   2614,
#   2615,
#   2616,
#   108,
#   7257,
#   6242,
#   7159,
#   5665,
#   3189,
#   3190,
#   2251,
#   1456,
#   667,
#   758,
#   759,
#   5168],
#  'pollakisurie': [4099, 2537, 4177, 982, 3274],
#  'alternativmedizinische methode zur wiederherstellung der darmflora': [919],
#  'abs': [920],
#  'serumkrea': [3884, 3887],
#  'krea': [3885,
#   3886,
#   3888,
#   3891,
#   2194,
#   732,
#   1687,
#   1694,
#   1534,
#   3981,
#   3983,
#   2340,
#   3264,
#   3265],
#  'gfr': [3889, 1688, 3131, 3620, 266, 2848, 2858],
#  'filterfunktion der nier': [3890, 3621, 2849],
#  'rr': [3894, 31, 2361, 2363, 2365, 2718, 1506, 1541],
#  'nephrotoxisch': [3895, 2253, 3110, 3111, 4358],
#  'circulus vitiosu': [3898],
#  'hamorrhoid': [7039],
#  'arterielle hypertonie': [1905,
#   2827,
#   761,
#   3765,
#   1184,
#   3112,
#   3113,
#   1780,
#   2962,
#   4055,
#   163,
#   1354,
#   3681,
#   2428,
#   1806,
#   2469,
#   1348,
#   1349,
#   2427,
#   4250,
#   620],
#  'symptome des oberen urogenitaltrakt': [2539],
#  'infektion des oberen urogenitaltrakt': [2540],
#  'symptome einer infektion des oberen urogenitaltrakt': [2541],
#  'spasmolytika': [3904],
#  'ein katheter mit gewundenem ende ': [3905,
#   1026,
#   1027,
#   780,
#   781,
#   782,
#   783,
#   4181,
#   564,
#   2473,
#   2474,
#   2475,
#   826,
#   662,
#   2037,
#   2038,
#   2039,
#   2040,
#   2041,
#   3399,
#   3400,
#   3401,
#   1371,
#   1262,
#   1263,
#   1264,
#   1265],
#  'symptom charakteristisch fur den nierenstein-abgang': [3906],
#  'glomerulonephriti': [342],
#  'nephrosklero': [343, 3674, 181, 3673, 909],
#  'kavernom': [2046],
#  'aneurysm': [2047],
#  'benig': [2049, 5126, 5983, 1378, 2685],
#  'malig': [2050, 1377],
#  'kreb': [2051],
#  'karzinom': [2054,
#   6056,
#   6510,
#   5774,
#   3642,
#   3643,
#   2198,
#   2199,
#   6801,
#   3078,
#   6850,
#   5861,
#   1387,
#   1388,
#   1389,
#   3345,
#   3346,
#   6967,
#   115,
#   6339,
#   727,
#   5561,
#   1513,
#   4718,
#   5271,
#   6278],
#  'protonenpumpen-inhibitor': [5839, 4803],
#  'arthralgie': [1644, 7129, 7120, 7203, 1492, 7232],
#  'hypophosphatamie': [1645],
#  'ohne pathologischen befu': [1647,
#   1648,
#   729,
#   5079,
#   4543,
#   151,
#   1893,
#   4439,
#   4442,
#   2761,
#   2762,
#   2553,
#   1699,
#   1613,
#   3610,
#   2019,
#   3027,
#   5161,
#   37,
#   3510,
#   333],
#  'harnwegsinfekt': [3170, 2255, 452, 573, 4009, 3405, 4443],
#  'adrenal fatigu': [4286, 1546],
#  'darmpar': [7294],
#  'neurog': [7295],
#  'par': [7296, 2291],
#  'prolap': [7299, 6016, 6017],
#  'ileum': [6528, 4921, 4922, 6922, 4989],
#  'minderperfusio': [1653, 6220],
#  'perfusio': [1654, 6219, 5386],
#  'aszendierende infektio': [3074],
#  'klistier': [5873, 6501, 5155, 7067, 7374, 6905, 6682],
#  'klysma': [5874, 5156, 7066, 7375, 6906],
#  'analspulung': [5875, 5157],
#  'darmspulung': [5876],
#  'bandscheibenprolap': [682, 684, 3928],
#  'protrusio': [683],
#  'hwi': [685, 373, 491, 2025],
#  'polyneuropathie': [688, 3934],
#  'neuropathie': [690, 3933, 7246, 7070, 2243],
#  'latu': [4054],
#  'cephalgie': [5460,
#   6568,
#   1582,
#   1890,
#   677,
#   2549,
#   7212,
#   5627,
#   1870,
#   3499,
#   7234,
#   4480,
#   756,
#   7205],
#  'pankreaskarzinom': [7011,
#   7012,
#   6367,
#   5251,
#   5367,
#   4646,
#   7258,
#   6170,
#   6171,
#   6003,
#   6533,
#   6886,
#   7058,
#   5604,
#   4826],
#  'endog': [6371],
#  'inflammatorisch': [6372, 7355],
#  'leaky gut syndrom': [6375, 5495],
#  'radix denti': [6376, 4632, 5493],
#  'leberinsuffizie': [6377],
#  'symptomregredienz': [6378, 6465],
#  'beschwerderegredienz': [6379],
#  'piktail': [4247],
#  'harnstau': [4249, 697, 4129],
#  'gastrointestinaltrakt': [5234, 30, 4366, 6625, 6626, 7091, 3267, 7305],
#  'hysterektomie': [1655],
#  'lymphadenektomie': [2449],
#  'eiweiss': [2450,
#   1181,
#   1817,
#   735,
#   2101,
#   2706,
#   1594,
#   3478,
#   1686,
#   2659,
#   4000,
#   3215,
#   3228,
#   2351,
#   1713,
#   1161,
#   1912,
#   1085,
#   324,
#   1518,
#   1593],
#  'glukosurie': [2451, 1182, 1167, 1596, 2352, 1162, 1086, 325],
#  'nephropathie': [2452, 1183, 1598, 2353, 1163, 1087, 334],
#  'hiatushernie': [4802, 6884, 6789, 5464, 5326],
#  'in-vitro-fertilisatio': [1719, 3353, 3354, 3358],
#  'blahung': [6327, 4587],
#  'hypochondrie': [6265, 4563, 7150, 778, 70, 970, 4737, 7308, 5186, 754],
#  'niereninsuffizie': [2831,
#   879,
#   3463,
#   3125,
#   4385,
#   4541,
#   3040,
#   4058,
#   2312,
#   4343,
#   2759,
#   2964,
#   3371,
#   3316,
#   4271,
#   2658,
#   4340,
#   69,
#   3969,
#   3936,
#   436,
#   2850,
#   2269,
#   2859,
#   2860,
#   1909,
#   141,
#   4421,
#   1376,
#   3247,
#   2969,
#   1520],
#  'afebril': [4875, 6786, 2550, 4962, 4967, 6515],
#  'analvenenthrombo': [6950,
#   6951,
#   6549,
#   5656,
#   6340,
#   5832,
#   5833,
#   5754,
#   5496,
#   6554,
#   5694,
#   5695,
#   7390],
#  'sphinkt': [7259, 6695, 5435, 5437, 7313, 5540, 7019, 7018, 7010, 5537, 5538],
# ...
#  'ischurie': [4537, 1052, 4496, 4497, 995, 196, 1130, 2164, 3278, 1008],
#  'allgemeinzusta': [1747],
#  'hamophilie': [1889],
#  'dyspnoisch': [1896, 6991],
#  'ha': [769, 3329, 1538, 4407, 4303, 3222, 2109, 2122, 1792],
#  'normotonu': [429, 258],
#  'gluco': [432, 3805, 177, 1003],
#  'eliminier': [738],
#  'leberinsuffizienz': [739],
#  'leberzirrho': [740, 829],
#  'schrumpfleb': [741],
#  'hyperammonamie': [742, 743],
#  'proteinzufuhr': [744],
#  'glomerulare filtrationsrat': [827],
#  'athyltoxisch': [828, 5704],
#  'athyltoxische leberzirrho': [830],
#  'nierenerkrankung': [832],
#  'follikelsprung': [4437, 2633],
#  'ovulatio': [4438, 2632],
#  'noroviru': [6973, 5568],
#  'nephropexie': [2869],
#  'pyelo': [4189, 4190, 2175, 2176, 746],
#  'urethrozystoskopie': [4308, 3769, 1036, 2904, 2773],
#  'blasenkarzinom': [4310, 4353, 4354, 1041],
#  'bakterienkultur': [4311, 4355, 4356, 1204],
#  'transpirier': [1227],
#  'urozystoskopie': [1975, 2684],
#  'bakteriurie': [3979, 3913, 3966, 498, 501, 4520],
#  'extrakorporale stosswellenlithotripsie': [1395, 1841, 3398, 1924],
#  'apoplex': [1150, 1578],
#  'hirninfarkt': [1151, 1577],
#  'hyperkaliamie': [1153],
#  'abgemag': [1156],
#  'polypharmazie': [1158],
#  'miktio': [3986, 3635],
#  'resektio': [5003, 5663, 379, 5096],
#  'entfernung': [5004, 4981],
#  'urs': [4044, 3426, 2821],
#  'erythrozyturie': [3310],
#  'langzeitkrank': [4344, 3319],
#  'chronisch': [4345, 4346, 2855, 3320, 3321],
#  'normvariant': [4347],
#  'resistente bakterien ': [194],
#  'laparotomie': [5713],
#  'unkurierbar': [4299, 6858],
#  'herzinsuffizienz': [4223, 4452, 4453, 7071, 1802, 3703],
#  'angina pectori': [6708,
#   6007,
#   5425,
#   4928,
#   6829,
#   6830,
#   6900,
#   5227,
#   5863,
#   5919,
#   5922,
#   7152,
#   7062,
#   7113,
#   5011,
#   5013,
#   5374,
#   2435,
#   2438,
#   5632,
#   5263],
#  'odemee': [3756],
#  'rezidivierende infektio': [4494],
#  'histaminintoleranz': [6477],
#  'alkoholkarenz': [6823, 4843],
#  'nikotinkarenz': [6824, 4842],
#  'proteinmangel': [2705, 331],
#  'odembildung': [2708],
#  'zu viel protein im uri': [2968],
#  'mukolytikum': [6935, 6936, 5721],
#  'ureth': [2093],
#  'harnrohrenstriktur': [2094],
#  'nierenwert': [990],
#  'magenulcu': [5409, 4741],
#  'ulcu': [5410, 6424, 4742, 5920, 6718, 5842],
#  'obstruktive uropathie': [3591, 2385, 2774],
#  'appendektomie': [1712, 4600, 5811, 5664, 5666],
#  'sklero': [6812],
#  'eingeweide des beck': [2602, 3602],
#  'metasta': [3077],
#  'alopezie': [5701, 5703],
#  'herzschwach': [4087],
#  'anxiolytika': [6088],
#  'gast': [6089,
#   6109,
#   6112,
#   6127,
#   6130,
#   6221,
#   6222,
#   6223,
#   6224,
#   6185,
#   7076,
#   7078,
#   7080,
#   7081,
#   6917,
#   4689,
#   5945],
#  'ventriculu': [6090,
#   6110,
#   6113,
#   6131,
#   6226,
#   6227,
#   6228,
#   6229,
#   6184,
#   7077,
#   7082,
#   7083,
#   7084,
#   7085,
#   6918,
#   4690,
#   5944],
#  'thyreoidektomie': [6092],
#  'glandula': [6095, 6096],
#  'blutzuck': [6098],
#  'herzra': [6101],
#  'echokardiografie': [6105, 5377],
#  'echokardiographie': [6106],
#  'arcus costali': [6115, 6193],
#  'tachykaradie': [6120],
#  'tachykard': [6126, 6134],
#  'mag': [6128, 7079],
#  'bradykardie': [6138],
#  'atemdepressio': [6140],
#  'uri': [3283, 1051, 4495, 3566, 1127, 1128, 187],
#  'fibro': [6650, 4663],
#  'sto': [641, 2697],
#  'interni': [264],
#  'perforierte appendiziti': [6307],
#  'hba1c': [4619, 6654],
#  'meteorisnu': [4622],
#  'harnverhalt': [1053, 4498, 1129, 3277],
#  'peritonealdialy': [1959],
#  'dyali': [1960, 1961],
#  'defakier': [6536, 6577],
#  'cholezystektomie': [6145, 7029],
#  'antibabypill': [3366, 3369, 2344, 1375],
#  'hormonelle kontrazeptiva': [3367, 3368],
#  'mylagie': [2548],
#  'l-thyroxi': [3330],
#  'pharyngiti': [5119],
#  'am ehesten symptom der gastroosophagealen refluxkrankheit': [6832],
#  'cholelithiasi': [6172, 4618, 3209, 4808, 2115, 4940],
#  'einer der symptome der b-symptomatik ': [6173],
#  'kongenitale nephrozirrho': [2462, 3657, 1602, 3786],
#  'abnehm': [3317],
#  'wichtsreduktio': [3318],
#  'normofrequ': [3322],
#  'endokrinologi': [1595],
#  'extrasytol': [5557],
#  'morbus-ormo': [424],
#  'fissur': [5869],
#  'uniklinik': [4317, 4318],
#  'hamodialy': [616],
#  'vorbeug': [617],
#  'bauchfelldialy': [618],
#  'herpes zost': [3081, 7179, 7182, 5297],
#  'probiotika': [6503],
#  'bun': [1685, 1697, 971],
#  'ck': [1690],
#  'gluko': [1692],
#  'nag': [1695],
#  'ngal': [1696],
#  'pyelektasie': [4014, 2012, 2013, 2020, 2021, 2023],
#  'pankrealgie': [1494],
#  'phlebiti': [2306],
#  'dol': [378, 380],
#  'nasennebenhohlenentzundung': [5054],
#  'kolikartig': [5056, 3266, 4367],
#  'btm': [2933],
#  'urolithiasi': [2938],
#  'weisse blutkorperch': [2940, 320, 6842],
#  'urographie': [1379],
#  'harnblasenkarzinom': [1383, 724],
#  'indol': [1791, 1294, 1295, 7211, 3299],
#  'gastroosophageale refluxkrankheit ': [7248],
#  'nierenbeckenentzundung': [1176],
#  'endokrinolog': [2886, 1064, 1084, 3269, 2059, 316],
#  'neuroendokriner tumor': [2887],
#  'neuroendokrine neoplasie': [2888],
#  'muku': [6230],
#  'kaiserschnitt': [5332, 5333, 4853, 4854, 362, 881],
#  'niernestei': [1185, 2225],
#  'hamorrhoiden / analfissur': [5850, 5776],
#  'koryza': [1940],
#  'nasenkatarrh': [1941],
#  'rhiniti': [1942],
#  'toxi': [5778],
#  'medi': [1535],
#  'op': [1929, 1288, 1727],
#  'nosokomiale infektio': [1932],
#  'hypoglykamie': [5765],
#  'aorta': [7055, 7106, 7108, 5387],
#  'normotensio': [4270],
#  'nierenbiopsie': [4207, 4208],
#  'nephrologi': [2148, 2621],
#  'mastdarm': [6579],
#  'fakalie': [6583],
#  'zystitis, urethriti': [6266],
#  'calcidiol': [3009],
#  'zirrho': [3010, 3011],
#  'gallenstei': [4939, 7031],
#  'hydrosi': [5780],
#  'magenatonie': [5782, 5784, 5786],
#  'mikrohaematurie': [2422, 384, 2337, 2070, 2071, 2072],
#  'diapetis insipidu': [1327],
#  'dehydrierung': [1329, 3916],
#  'diabetis mellitu': [1330],
#  'zuckerkrankheit': [1331],
#  'okkul': [1332, 510, 7195, 7196, 4821, 4822, 7306, 7307],
#  'maskier': [1333],
#  'defliblirator': [4448],
#  'gicht': [4450, 4451, 2401, 2402],
#  'sono-abdom': [4614, 2670, 2674, 2677, 2681],
#  'abdomen-sonographie': [4615, 7057, 4820],
#  'oligosymptomatisch': [4202, 7138, 2562],
#  'coliti': [5256, 5268],
#  'scapula': [1789, 5179],
#  'fundusgastriti': [5317],
#  'egfr': [3984],
#  'azoospermie': [3355, 3356, 3357],
#  'hypozoospermie': [3359],
#  'bandscheibenvorfall': [3931],
#  'durch nierenstein verursachte obstruktion des uret': [487],
#  'komorbiditat': [7177],
#  'somnolenz': [7178, 6802],
#  'mundsoor': [6304, 5113, 7199, 7157, 6406, 7218],
#  'abdomen-sonografie': [2671, 2675, 2678, 2682],
#  'hypertroph': [2686],
#  'uteru': [2687],
#  'antazid': [5741, 5432],
#  'dysbio': [5744],
#  'skolio': [2776, 7061],
#  'symptom einer akuten entzundung der niere / des nierenbeck': [2777],
#  'schilddrusenadenom': [2778],
#  'kardiolog': [4926],
#  'antipyretikum': [1336],
#  'nierenszintigraphie ': [3612],
#  'lymphadenopathie': [3033, 322],
#  'faszikulatio': [6472],
#  'normoglykamie': [1059, 3136, 557],
#  'divertikel': [4919, 4920, 5586, 6919, 6937, 6639],
#  'urinstix': [395],
#  'bewegungsschmerz': [507],
#  'rezidivierende flankenschmerz': [515],
#  'mittelstrahluri': [519],
#  'sectio caesarea': [5346, 32],
#  'wehenartig': [1279],
#  'darmparaly': [6021],
#  'paraly': [6022],
#  'pravesikal': [246, 2560, 2561],
#  'alkoholismu': [2407],
#  'fructo': [5359, 6984],
#  'foetor ex or': [5362],
#  'halitosi': [5363, 5259],
#  'mamma-karzinom': [3335],
#  'mastektomie': [3337],
#  'radiatio': [3338],
#  'strahlentherapie': [3339],
#  'serom': [3340, 3344, 3343],
#  'partielle mastektomie': [3348],
#  'urethralabstrich': [2087, 3603],
#  'endokrinologisch': [2770, 6965],
#  'nebennierenkarzinom': [4584],
#  'laparoskopie': [4601, 489, 5500, 6903],
#  'postinfektio': [3974],
#  'pektanginose beschwerd': [5777, 4652, 6816, 6817],
#  'symptom der oralen candidose ': [6297],
#  'bes': [715],
#  'alopecia': [4096],
#  'symptom am ehesten bedingt durch muskelkontraktionen aufgrund von nierenstein-abgang': [161],
#  'symptom  bedingt durch muskelkontraktionen aufgrund von nierenstein-abgang': [162],
#  'akutes abdom': [5769],
#  'praventio': [7197, 5154, 7373],
#  'zystitiden ': [1566],
#  'intravenose analgesie': [4024, 106, 116],
#  'proteingehalt': [1628],
#  'eiweisswert': [1629],
#  'symptome einer akuten nierenbeckenentzundung': [1901],
#  'abzess': [7128],
#  'dermatiti': [7132, 5368],
#  'arthriti': [7133, 1091],
#  'lympholog': [3093],
#  'ws': [1322],
#  'bauchhohl': [5587],
#  'ureteroskopie': [3425, 2818],
#  'anasthesist': [3428],
#  'rx': [3440],
#  'ovarial-karzinom': [6968],
#  'nodulu': [5657, 6324],
#  'krankenkass': [304],
#  'huftgelenk': [1339],
#  'seh': [1340],
#  'antihypertensivum': [6523, 3870],
#  'antivertiginosa': [4260],
#  'lebensmittelintoxikatio': [5680],
#  'digestio': [5682],
#  'atemnot': [6552],
#  'laktosefrei': [6495],
#  'pankreasinsuffizienz': [5831],
#  'iv': [3664],
#  'labia': [3172],
#  'hyperglykamische entgleisung': [5301],
#  'diffu': [5302],
#  'graviditat': [2009, 7092, 1190],
#  'statio': [2010, 7093, 1189],
#  'alkoholabsti': [2610],
#  'polyp': [5343],
#  'caecum': [2488],
#  'pangastriti': [4716],
#  'duodeniti': [4717],
#  'harnwegsinfektio': [1239],
#  'pyelonephritis ': [4171],
#  'myokarditi': [6158],
#  'rhinopharyngiti': [6159],
#  'nephritid': [3559],
#  'unauffallig': [2261, 4146],
#  'postprandiale ubelkei': [5226],
#  'nuchtern-bb': [3801],
#  'glc': [3802],
#  'glc i.': [3803],
#  'i.s': [3804, 267],
#  'bz': [3806],
#  'duodenalmukosa': [4669],
#  'duodenal': [4671],
#  'zoliakie': [4673,
#   4674,
#   7330,
#   7334,
#   7336,
#   7337,
#   7342,
#   7343,
#   7345,
#   6846,
#   5830,
#   7316],
#  'hyperplasie': [4677, 4678],
#  'miktionszystourethrografie': [1429],
#  'entzundungsparamet': [4094],
#  'hamatom': [3295, 3296, 3470, 71],
#  'biopsier': [3298],
#  'magenulkus ': [5252],
#  'inappetenz': [6972],
#  'hepatopathie': [7347],
#  'laxa': [1564],
#  'eswl ': [3695, 2863],
#  'testalgie': [4372],
#  'condylomata acuminata': [6062, 6063],
#  'glutensensitive enteropathie': [7331, 7335, 7344, 6847, 5829],
#  'lymphom': [7341],
#  'symptom der nierenbeckenentzundung': [2577],
#  'urethraobstruktio': [5789],
#  'kontaminier': [6306],
#  'magen reflux': [5864],
#  'agoraphobie': [6195],
#  'myokardschad': [6196, 7060],
#  'herzvitie': [6198],
#  'fa': [3545],
#  'mittel zur hormonellen empfangnisverhutung ': [3547],
#  'hypocalzamie': [4334],
#  'calciphylaxie': [4335],
#  'atherosklero': [4336],
#  'arteriosklero': [4337],
#  'nierenbeckenentzundung ': [1254],
#  'clavicula': [535],
#  'zentralvenenkathet': [536],
#  'zvk': [537],
#  'diatologi': [540],
#  'lumbago': [4302],
#  'proktolog': [5549, 7009],
#  'sklerosierung': [5551],
#  'hoden ': [892],
#  'norovirus-infektio': [5801, 5371],
#  'akute gastroenteriti': [5802],
#  'struktur': [87],
#  'kongenitale striktur': [96],
#  'kongenitale steno': [97],
#  'intraveno': [107, 117, 1580],
#  'verwachsung': [113],
#  'schamlipp': [3301, 3147],
#  'sassback': [3302],
#  'beckenkamm': [3303],
#  'dysgeusie': [6033],
#  'kranielle mr': [5727],
#  'abdomensonographie': [5728],
#  'gastro-koloskopie': [4132],
#  'kollik': [4138],
#  'osteochondro': [4139],
#  'laparoskopisch': [1731],
#  'magenspiegelung': [7348],
#  'zystitid': [905, 908],
#  'conn-syndrom': [4263],
#  'chronisch infizier': [3789],
#  'dringlich': [4535],
#  'gastroosophagealer reflux': [4804],
#  'bili': [3614],
#  'sklerenikteru': [3616],
#  'cholesta': [3617],
#  'gallengangssteno': [3618],
#  'acholischer stuhl': [3619],
#  'hkt': [3622, 3630],
#  'ery': [3623],
#  'thrombozyt': [3624, 1531, 1532],
#  'leuko': [3627],
#  'sas': [3628],
#  'epo': [3629],
#  'lithotripsie': [3007],
#  'intermittierende cephalgie': [7204, 7236],
#  'parageusie': [7207, 7237],
#  'palpier': [7329],
#  'sodbrenn': [4756],
#  'sternum': [4757],
#  'speiserohrenentzundung': [4771],
#  'spru': [4772],
#  'fruktoseintoleranz': [4781, 4782, 4784],
#  'exazerbier': [4800, 7225],
#  'verzicht': [4801],
#  'akute pankreatiti': [6652],
#  'pankreatiti': [6653, 5062, 5021, 5043],
#  'anafissur': [6628],
#  'hf': [2719],
#  'virale gastroenteriti': [5836],
#  'myopathie': [7069],
#  'kardiomegalie': [7059],
#  'intermittierende diarrho': [4965],
#  'infektbedingte diarrho': [4973],
#  'trigeminusneuralgie': [2246],
#  'subileu': [4814, 5990],
#  'inkarzeratop': [4815],
#  'praprandial': [7090],
#  'extrasytsol': [7109],
#  'proteinverlust': [3867],
#  'unter konservativer behandlung': [3596],
#  'vagina': [4525],
#  'stearrho': [6634],
#  'pankreasstuhl': [6635],
#  'raumforderung': [5625],
#  'cardiainsuffizienz': [5354, 5355],
#  'muskeltonu': [4476],
#  'nephropexie: operatives verfahren aus der urologie zur fixierung einer wanderniere ': [4478],
#  'chronische pyelonephriti': [4321],
#  'hernie': [5159, 6440],
#  'zystennier': [4081],
#  'hypothyreo': [180, 2141, 2418],
#  'hypertensive kri': [6284],
#  'hypertensiver notfall': [6285],
#  'euthyreo': [6292, 4473, 4472],
#  'fibrom': [5756],
#  'rheumatoide arthriti': [5567],
#  'urolith': [3145, 3148],
#  'diur': [4326],
#  'hypochondrisch': [4327],
#  'sta': [655],
#  'fiebrig': [3961],
#  'febril': [3962],
#  'fieberhaf': [3963],
#  'schrumpfnier': [4211, 1444, 381, 600],
#  'breitbandantibiotikum': [3565],
#  'rectum': [6913],
#  'sigma': [6914, 6915, 6916],
#  'vertebragene ruckenschmerz': [621],
#  'analgesie': [3127],
#  'tinnitu': [1859, 3583],
#  'diplopie': [1860],
#  'allodynie': [1871],
#  'sonigraphie': [426],
#  'melana': [6392],
#  'nephrolithiasi': [4029],
#  'nierenstau': [3068],
#  'klysm': [6004, 6005],
#  'sonographie des abdom': [5378, 5382],
#  'psychosomatik': [5379],
#  'herzrhythmusstorung': [5381],
#  'nykturie': [2110, 3272],
#  'krankenhau': [2123],
#  'tsh': [2124, 2125],
#  'samtprotei': [2127],
#  'blinddarmentzundung': [2136],
#  'infusio': [2140],
#  'schilddrusenunterfunktio': [2142],
#  'laryngiti': [6679],
#  'mutterleib': [1236],
#  'craniale computertomographie ': [1238],
#  'laparoskopier': [6904],
#  'verdauung': [7027],
#  'protonenpumpen-inhibitor ': [7032],
#  'gynakolog': [3504, 318],
#  'wehenartiger nierenschmerz': [3252],
#  'internisti': [1099],
#  'endoskopier': [5845],
#  'bb': [2433, 1508, 1509],
#  'eiweisszufuhr': [1911],
#  'hypothermie': [3714],
#  'hyperkypho': [182],
#  'ubertragener schmerz': [183],
#  'pyelonephritid': [2145],
#  'nierenkolik-schmerz': [2335],
#  'entzundliche prozesse im hals-rachen-bereich': [1326],
#  'haematurie': [2338],
#  'antidiarrhoikum': [4957],
#  'ureterorenoskopie ': [4065],
#  'hypocalcamie': [2668],
#  'ap': [2669],
#  'langzeit-rr': [760],
#  'dj-harnleiterschie': [2736],
#  'ulcus duodeni': [2724],
#  'glucosurie': [1083],
#  'otitis media': [710, 230],
#  'nnr': [1065],
#  'rhonchopathie': [1066],
#  'hypoglykamisch': [4749],
#  'oraler glukosetoleranztest': [4752],
#  'hypoglykamsich': [4753],
#  'b12': [2234],
#  'antimykotika': [6411],
#  'nierensonographie': [1807],
#  'infrascapular': [5178],
#  'hormonelles kontrazeptivum': [1374],
#  'peritonealkathet': [2764],
#  'ureterabgang': [201],
#  'hepatomegalie': [3582],
#  'renomegalie': [3585],
#  'hochstwahrscheinlich geht es hier um ein symptom der akuten nierenbeckenentzundung ': [2983],
#  'urethramundung': [2166],
#  'irrigoskopie': [6684],
#  'miktionsstorung': [6687],
#  'atrophie': [5996],
#  'anamisch': [6001],
#  'c2': [3258],
#  'zystometrie': [3260],
#  'supravesikale harnabflussstorung': [1622],
#  'orale candido': [7226],
#  'tremor': [7233],
#  'magensaureruckfluss': [6446, 7017, 5261],
#  'divertikulo': [6447],
#  'hypertrophie': [4693],
#  'hiatus osophageu': [6276],
#  'mukositi': [5949, 647],
#  'niernstei': [1370],
#  'glandula thyreoidea': [7040],
#  'nes': [7304],
#  'leichte niereninsuffizienz': [2654],
#  'be': [1542],
#  'omalgie': [7014],
#  'scheideninfektio': [1393],
#  'mucosa': [646],
#  'vertebral': [579, 580],
#  'osophaguskarzinom': [5262],
#  'hamoly': [1527, 1529],
#  'predni': [4467],
#  'sd': [4468],
#  'chorionbiopsie': [3669, 3670],
#  'rektoskopie': [6321],
#  'nodu': [6325],
#  'aerophagie': [4683],
#  'computertomographie': [319],
#  'zervikale lymphadenopathie': [323],
#  'zu flussiges blu': [329],
#  'eiweissmangel': [330],
#  'beck': [1590],
#  'symptom der nierenbeckenentzundung ': [2380],
#  'symptom der entzundlichen nierenerkrankung': [2381],
#  'fertil': [1409],
#  'infertil': [1410],
#  'padiatrie': [568],
#  'steissbei': [4101],
#  'sass': [637],
#  'nierenkrank': [2971],
#  'symptome der gastroosophagealen refluxkrankheit': [6895],
#  'herzstolp': [5129, 5131],
#  'ncc': [1031],
#  'nierenzellkarzinom': [1032],
#  'diabest': [2833, 2835],
#  'ergebnis der teststreifen-urin-untersuchung, vereinbar mit bakterieller harnwegsinfektio': [248],
#  'appendix': [5093],
#  'bakterielle urethriti': [2742],
#  'atopische dermatiti': [6281],
#  'atopisches ekz': [6282],
#  'endogenes ekz': [6283]}

# %%
# all_annotation_ids = []
# for annotation_ids in search_terms.values():
#     all_annotation_ids.extend(annotation_ids)
# len(all_annotation_ids), len(set(all_annotation_ids))

# %%
# with jsonlines.open(TLCPaths.project_data_path.joinpath("TLC-UMLS-v4-reviewed-validated.jsonl")) as reader:
#     validated_samples = [obj for obj in reader]
# accepted_samples = [sample for sample in validated_samples if sample["answer"] == "accept"]
# rejected_samples = [sample for sample in validated_samples if sample["answer"] == "reject"]
# ignored_samples = [sample for sample in validated_samples if sample["answer"] == "ignore"]
# 
german_umls_cuis = set()
with open(TLCPaths.project_data_path.joinpath("german_umls_names_and_cuis.csv"), newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in reader:
      assert len(row)== 2
      german_umls_cuis.add(row[0])

tlc_samples = []
for file in TLCPaths.json_dir.iterdir():
    sample = Sample.parse_file(file)
    tlc_samples.append(sample)

def get_sample_for_annotation_id(annotation_id):
    for sample in tlc_samples:
        sample_ann_ids = [ann.id for ann in sample.annotations]
        if annotation_id in sample_ann_ids:
            return sample

def substring_indices(main_string, substring):
    indices = []
    start = 0
    while True:
        start = main_string.find(substring, start)
        if start == -1: return indices
        end = start + len(substring)
        indices.append((start, end))
        start = end

def get_tlc_annotation(annotation_id, tlc_annotations):
    return next(ann for ann in tlc_annotations if ann.id == annotation_id)

# %%
# use third round annotations instead
with open(TLCPaths.project_data_path / "third_round_finished_annotations.json", "r") as fp:
    third_round_annotations = json.load(fp)

# %%
third_round_annotations
# Out:
# {'1401678599': {'text': 'Thread: [Unerklärliche Bauchschmerzen]\nText: [Hallo!\nAuch ich dachte laut der Beschwerden von einigen von euch gleich an Gallensteine.\nBeim Ultraschall muss man komplett nüchtern sein, d.h. nicht mal Wasser trinken vorher, sonst kann man bei der Gallenblase nichts erkennen. Es gibt auch Gallensteine in den Gallengängen, wobei leider eine Ultraschalluntersuchungen meistens nicht reicht um diese zu erkennen. Da kann man eine ERCP (Sp\\u00edegelung) machen.\nObwohl ich aber glaube, dass sie eure Ärzte die einen Oberbauchultraschall bei euch gemacht haben, sich die Gallenblasen sicher genau angesehen haben, da die Beschwerden ja auch dafür in Frage kommen.]\n',
#   'spans': [{'start': 121, 'end': 133, 'label': 'Mention'}],
#   'html': '<b>C0008350</b>: Cholelithiasis: Vorhandensein oder Bildung von Gallensteinen im Gallentrakt, meist in der Gallenblase (CHOLECYSTOLITHIASIS) oder im Hauptgallengang (CHOLEDOCHOLITHIASIS).',
#   'annotation_ids': [6202, 6147, 4618],
#   'cui': 'C0008350',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0008350'},
#   '_input_hash': 1401678599,
#   '_task_hash': -1479767773,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1682059773,
#   '_annotator_id': 'TLC-validation_v4-alon',
#   '_session_id': 'TLC-validation_v4-alon'},
#  '1983979031': {'text': 'Thread: [Magen Darm Grippe in Dauerschleife]\nText: [Wie kann es dann aber sein, dass nur sie sich immer wieder neu ansteckt und wir anderen drei noch nicht?]\n',
#   'spans': [{'start': 9, 'end': 26, 'label': 'Mention'}],
#   'html': '<b>C2242683</b>: Gastroenteritis Norovirus',
#   'annotation_ids': [5687,
#    6480,
#    4942,
#    6041,
#    6081,
#    6342,
#    5686,
#    6848,
#    4131,
#    5569,
#    6803,
#    4987],
#   'cui': 'C2242683',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C2242683'},
#   '_input_hash': 1983979031,
#   '_task_hash': 1620652852,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1682059846,
#   '_annotator_id': 'TLC-validation_v4-alon',
#   '_session_id': 'TLC-validation_v4-alon'},
#  '1587311592': {'text': 'Thread: [Appetitlosigkeit]\nText: [Hallo Liebe med1 Mitglieder,\nVorgeschichte in der Kurzfassung:\n- Sept 16 - März 17 linke Unterbauchschmerzen bis der Blinddarm im März rauskam (war nicht entzunden, aber Verwachsung wurden gelöst)\n- März 17 ist mein Daddy nach langem Kampf gg Leberzirrhosen mit multiplem Organversagen gestorben\n- Gastritis Typ C - Pantropazol bei Bedarf\nNun das Problem:\nSeit ca. 4 Monaten hab ich echt wenig Hunger. Teils gar nicht, teils bin ich so schnell satt.\nSelbst nach einem Tag mit Bergtour 0 Appetit.\nSind das noch die Folge der o.g. Ereignisse durch die Belastungen (auch Psyche) und des \\verlernen\\ des viel essens oder sollte man das doch mal abklären?! (War eigtl immer eine sehr gute Esserin).\nNur selbst wenn ich mehr esse denk ich mich zerreist es od ich muss mich übergeben.\nAbnehmen tu ich jedoch nicht.\n(1,75 cm, 64 kg, 30 Jahre)\nBsp. Heute Hunger ohne Ende auf Arbeit. 5 min Terrine gegessen und war selbst da nach der Hälfte satt. (War aber auch net der Hammer). Nun abends zwar was gegessen, aber 0 Hunger. Wäre auch ohne gegangen.\nLg]\n',
#   'spans': [{'start': 151, 'end': 176, 'label': 'Mention'}],
#   'html': '<b>C0085693</b>: Akute Appendizitis NOS (Störung)',
#   'annotation_ids': [5401],
#   'cui': 'C0085693',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0085693'},
#   '_input_hash': 1587311592,
#   '_task_hash': 877398727,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1682059921,
#   '_annotator_id': 'TLC-validation_v4-alon',
#   '_session_id': 'TLC-validation_v4-alon'},
#  '1676438464': {'text': 'Thread: [Nach Darm Op alles aus dem Gleichgewicht, kann das sein?]\nText: [Hallo zusammen,\nich hatte vor längerer Zeit eine Darm OP mit Teilstückentfernung des Dickdarms. ca. 2 Jahre später eine Hernie am Bauchnabel wohl entstanden durch die Darm OP mit diversen den Bauchschnitten.\nSeit dieser Op finde ich ist meine gesundheit durcheinander bzw. das Immunsysthem/Stoffwechsel.\nich bin sehr oft krank mit diversem. Auch leider so langsam Stück für Stück das Gewicht. Das stört mich sehr.\nKann es da einen Zusammenhang geben? Ganz zu Schweigen das ich nicht mehr alles essen kann/ vertrage.\nDanke und ein schönes WE ]\n',
#   'spans': [{'start': 135, 'end': 168, 'label': 'Mention'}],
#   'html': '<b>C0149750</b>: Teilweise Resektion des Dickdarms: Chirurgische Entfernung eines Teils des Dickdarms.',
#   'annotation_ids': [5463],
#   'cui': 'C0149750',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0149750'},
#   '_input_hash': 1676438464,
#   '_task_hash': -1822704334,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1682155478,
#   '_annotator_id': 'TLC-validation_v4-alon',
#   '_session_id': 'TLC-validation_v4-alon'},
#  '-117754993': {'text': 'Thread: [Harnleiterschiene, werden die Schmerzen besser?]\nText: [Der rote Urin ist relativ normal. Kannst es aber gerne zu deiner Beruhigung noch mal abklären lassen.\nVielleicht ist das auch in jedem Haus etwas anders geregelt, wann die Steine geholt werden.]\n',
#   'spans': [{'start': 69, 'end': 78, 'label': 'Mention'}],
#   'html': '<b>C1822257</b>: Sichtbares Blut im Urin',
#   'annotation_ids': [609, 610, 611],
#   'cui': 'C1822257',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C1822257'},
#   '_input_hash': -117754993,
#   '_task_hash': -259236404,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1682155512,
#   '_annotator_id': 'TLC-validation_v4-alon',
#   '_session_id': 'TLC-validation_v4-alon'},
#  '-430989661': {'text': 'Thread: [Niereninsuffizienz und Zeugungsfähigkeit?]\nText: [mein mann hat bislang noch keine nennenswerten beschwerden durch seine nierenerkrankung. er befindet sich zwische dem zweiten und dritten stadium. einen leichten bluthochdruck hat er allerdings. den hatte er soweit ich weiß auch schon vor seiner erkrankung. diabetes und durchblutungsstörungen hat er soweit ich weiß nicht. er nimmt ab und an ace-hemmer aber die könnten wir bei einem kinderwunsch auch kurzzeitig absetzen denke ich. wir sind (leider) noch ziemlich jung. ich bin 28 und er 30.\nwürde es denn auch etwas bringen wenn er seine spermien jetzt einfrieren lassen würde falls auch später nochmal ein kinderwunsch bestehen sollte oder hälst du das eher für unnötig?]\n',
#   'spans': [{'start': 600, 'end': 625, 'label': 'Mention'}],
#   'html': '<b>C0519952</b>: Kryokonservierung von Spermatozoen',
#   'annotation_ids': [210],
#   'cui': 'C0519952',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0519952'},
#   '_input_hash': -430989661,
#   '_task_hash': 1792309938,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1683809196,
#   '_annotator_id': 'TLC-validation_v4-selin',
#   '_session_id': 'TLC-validation_v4-selin'},
#  '282774286': {'text': 'Thread: [Wasser im Nierenbecken]\nText: [Wie soll ich denn diese Antwort verstehen ?]\n',
#   'spans': [{'start': 19, 'end': 31, 'label': 'Mention'}],
#   'html': '<b>C0227666</b>: Nierenbecken: Die abgeflachte, trichterförmige Erweiterung, die den URETER mit den KIDNEY CALICES verbindet.',
#   'annotation_ids': [4241,
#    3328,
#    4189,
#    4190,
#    4217,
#    2386,
#    2175,
#    2176,
#    2027,
#    2028,
#    746,
#    643],
#   'cui': 'C0227666',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0227666'},
#   '_input_hash': 282774286,
#   '_task_hash': 1428549304,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1687772580,
#   '_annotator_id': 'TLC-validation-second-round-alon',
#   '_session_id': 'TLC-validation-second-round-alon'},
#  '1844465086': {'text': 'Thread: [Nierenwerte Schwankung möglich]\nText: [Wenn du tatsächlich erst 24 Jahre sein solltest, erscheint mir das Serumkreatinin zu hoch. Allerdings nanntest du keinen Referenzbereich, welcher für Männer und Frauen leicht unterschiedlich ist. Dies aus dem Grund, weil Männer mehr Muskelmasse haben. Der Kreatininwert wird durch eine hohe Muskelmasse beeinflusst. Wenn du beispielsweise vor der Messung intensiv Sport gemacht hast oder viel Fleisch gegessen hast, kann der Serumkreatintinwert auch deshalb höher sein als üblich.\nDie GFR (glomeruläre Filtrationsrate der Nieren) sinkt hingegen mit steigendem Kreatinin.\nZu hoher Blutdruck schädigt auf Dauer jedenfalls die Nieren und geschädigte Nieren verursachen hohen Blutdruck. Das ist sozusagen ein Teufelskreis. Kontrollierst du deinen Blutdruck regelmäßig? Ist er schon länger durch die Bank grenzwertig (hoch)? Oder war das nur einmalig?\nDu solltest deine Nierenwerte gelegentlich noch mal überprüfen lassen.]\n',
#   'spans': [{'start': 115, 'end': 129, 'label': 'Mention'}],
#   'html': '<b>C0201976</b>: Kreatininmessung, Serum (Verfahren): Eine quantitative Messung der in einer Serumprobe vorhandenen Kreatininmenge.',
#   'annotation_ids': [3884],
#   'cui': 'C0201976',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0201976'},
#   '_input_hash': 1844465086,
#   '_task_hash': 1913155065,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1682155866,
#   '_annotator_id': 'TLC-validation_v4-alon',
#   '_session_id': 'TLC-validation_v4-alon'},
#  '970771144': {'text': 'Thread: [Nierenwerte Schwankung möglich]\nText: [Wenn du tatsächlich erst 24 Jahre sein solltest, erscheint mir das Serumkreatinin zu hoch. Allerdings nanntest du keinen Referenzbereich, welcher für Männer und Frauen leicht unterschiedlich ist. Dies aus dem Grund, weil Männer mehr Muskelmasse haben. Der Kreatininwert wird durch eine hohe Muskelmasse beeinflusst. Wenn du beispielsweise vor der Messung intensiv Sport gemacht hast oder viel Fleisch gegessen hast, kann der Serumkreatintinwert auch deshalb höher sein als üblich.\nDie GFR (glomeruläre Filtrationsrate der Nieren) sinkt hingegen mit steigendem Kreatinin.\nZu hoher Blutdruck schädigt auf Dauer jedenfalls die Nieren und geschädigte Nieren verursachen hohen Blutdruck. Das ist sozusagen ein Teufelskreis. Kontrollierst du deinen Blutdruck regelmäßig? Ist er schon länger durch die Bank grenzwertig (hoch)? Oder war das nur einmalig?\nDu solltest deine Nierenwerte gelegentlich noch mal überprüfen lassen.]\n',
#   'spans': [{'start': 791, 'end': 800, 'label': 'Mention'}],
#   'html': '<b>C0005823</b>: Blutdruck: DRUCK des BLUTES auf die ARTERIEN und andere BLUTGEFÄSSE.',
#   'annotation_ids': [3894, 31, 2361, 2363, 2365, 2718, 1506, 1541],
#   'cui': 'C0005823',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0005823'},
#   '_input_hash': 970771144,
#   '_task_hash': -1744808847,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1683809240,
#   '_annotator_id': 'TLC-validation_v4-selin',
#   '_session_id': 'TLC-validation_v4-selin'},
#  '-298817693': {'text': 'Thread: [Zu viel Eiweiß im Urin, Nieren filtern nicht richtig]\nText: [Hallo,\neine Proteinurie kann vielerlei Ursachen haben, evtl. handelt es sich um ein frühes Stadium einer Nephropathie. Weißt Du zufällig, welches / welche Protein(e) genau im Urin nachgewiesen worden sind? Albumin, IgG, Alpha-Mikroglobulin? Leidest Du unter Diabetes mellitus oder Bluthochdruck?\nEinen unmittelbaren Zusammenhang zum bisher unerfüllten Kinderwunsch sehe ich zunächst mal nicht.\nViele Grüße,]\n',
#   'spans': [{'start': 351, 'end': 364, 'label': 'Mention'}],
#   'html': '<b>C0020538</b>: Bluthochdruck-Krankheit: Das Vorhandensein eines chronisch erhöhten Drucks im systemischen arteriellen System. [HPO:probinson]',
#   'annotation_ids': [1905,
#    4349,
#    4350,
#    3994,
#    3995,
#    2180,
#    2181,
#    2182,
#    2183,
#    2827,
#    4159,
#    4160,
#    3050,
#    3051,
#    1879,
#    1880,
#    1881,
#    1882,
#    4294,
#    4295,
#    3765,
#    1916,
#    1917,
#    5144,
#    5145,
#    5146,
#    5147,
#    2590,
#    2591,
#    2884,
#    2885,
#    1184,
#    3112,
#    3113,
#    1735,
#    1736,
#    2962,
#    660,
#    661,
#    2694,
#    2695,
#    4257,
#    4258,
#    459,
#    460,
#    4055,
#    1625,
#    163,
#    4261,
#    4262,
#    2721,
#    2722,
#    3868,
#    3869,
#    3873,
#    3874,
#    2368,
#    2369,
#    1862,
#    1863,
#    5673,
#    5674,
#    3681,
#    2922,
#    2923,
#    2926,
#    2927,
#    3496,
#    3497,
#    3506,
#    3507,
#    1107,
#    1108,
#    1109,
#    1110,
#    2427,
#    2060,
#    2061,
#    1777,
#    1778,
#    4250,
#    620,
#    2469,
#    1348,
#    6279,
#    6280],
#   'cui': 'C0020538',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0020538'},
#   '_input_hash': -298817693,
#   '_task_hash': 1711377321,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1683809339,
#   '_annotator_id': 'TLC-validation_v4-selin',
#   '_session_id': 'TLC-validation_v4-selin'},
#  '-54540277': {'text': 'Thread: [Nebennierenschwäche]\nText: [Hi leute \nKennt sich jemand von euch mit dieser Krankheit aus \\ Adrenal Fatigue\\ was leider in der Schulmedizin kaum angsehen wird.. Hätte ein paar fragen dazu, bitte privat schreiben falls jemand mir helfen kann ]\n',
#   'spans': [{'start': 101, 'end': 116, 'label': 'Mention'}],
#   'html': '<b>C0001623</b>: Unterfunktion der Nebennierendrüse: Zustände, bei denen die Produktion von Nebennieren-Corticosteroiden unter dem Bedarf des Körpers liegt. Eine Nebenniereninsuffizienz kann durch Defekte der Nebennierenrinde, der Nebennierenrinde oder des Hypothalamus verursacht werden.',
#   'annotation_ids': [4286],
#   'cui': 'C0001623',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0001623'},
#   '_input_hash': -54540277,
#   '_task_hash': -2104720048,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1682156024,
#   '_annotator_id': 'TLC-validation_v4-alon',
#   '_session_id': 'TLC-validation_v4-alon'},
#  '-1530154787': {'text': 'Thread: [Histamin Intoleranz, durchlässiger Darm]\nText: [Also ich bin mir schon ziemlich sicher dass man an \\Histamin im Stuhl\\ höchstens erkennen kann, ob man was histaminreiches gefuttert hat, aber ganz bestimmt nicht, wie gut der Abbau im Blut/Gewebe funktioniert. Wie sollte das denn auch möglich sein!?\nAnsonsten gibts ja nur zwei Möglichkeiten, wenn man derartige Beschwerden hat:\n1. der Abbau ist gestört. Das muss dann abrupt bei Beginn der Beschwerden passiert sein. War da was? Doch leberkrank? :D\n2. es wird mehr Histamin produziert (endogen), als, zusammen mit dem mit der Nahrung zugeführten,. abgebaut werden kann. Das kann an chronisch entzündlichen Prozessen liegen (versteckte Zahnwurzel-Entzüdnungen, chronische Nebenhöhlen-Entzündungen wären  da ein Faktor), oder ggf auch am Leaky Gut Syndrom, so es denn existiert.\nDie Behandlung kann symptomatisch sein (kein Histaminzeugs mehr essen) oder ursächlich (nicht mehr den Darm mit Weizen traktieren, Zähne und NNH gesund machen) oder beides.\nBei Verzicht auf Histamin in der Nahrung sollte innerhalb weniger Tage eine Besserung zu spüren sein, so es denn wirklich daran liegt.]\n',
#   'spans': [{'start': 694, 'end': 704, 'label': 'Mention'}],
#   'html': '<b>C0040452</b>: Struktur der Zahnwurzel: Der Teil eines Zahns, der vom Zahnhals bis zur Wurzelspitze reicht, in den Alveolarfortsatz eingebettet und mit Zement überzogen ist. Eine Wurzel kann einzeln oder in mehrere Äste unterteilt sein, die in der Regel durch ihre relative Position gekennzeichnet sind, z. B. linguale oder bukkale Wurzel. Zu den einwurzeligen Zähnen gehören die ersten und zweiten Prämolaren des Unterkiefers und die zweiten Prämolaren des Oberkiefers. Der erste Prämolar des Oberkiefers hat in den meisten Fällen zwei Wurzeln. Die Oberkiefermolaren haben drei Wurzeln. (Jablonski, Wörterbuch der Zahnmedizin, 1992, S. 690)',
#   'annotation_ids': [6376],
#   'cui': 'C0040452',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0040452'},
#   '_input_hash': -1530154787,
#   '_task_hash': 393193626,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1682156097,
#   '_annotator_id': 'TLC-validation_v4-alon',
#   '_session_id': 'TLC-validation_v4-alon'},
#  '528286105': {'text': 'Thread: [Niereninsuffizienz und Zeugungsfähigkeit?]\nText: [danke die prompte antwort :) wir werden demnächst eine untersuchung durchführen. kannst du villeicht eine ungefähre einschätzung deiner persönlichen erfahrung machen wie die quote bei den männern aussah? also kennst du mehr männer bei denen es unter der dialyse klappte oder mehr bei denen es nicht funktionierte? und stünden die chancen einer künstlichen befruchung im schlimmsten falle gut?\nich weiß es sind viele fragen und ich kann nicht erwarten dass du sie mir genau beantwortest aber fragen kostet ja bekanntlich nichts ]\n',
#   'spans': [{'start': 403, 'end': 425, 'label': 'Mention'}],
#   'html': '<b>C0733942</b>: Begegnung aufgrund einer In-vitro-Fertilisation',
#   'annotation_ids': [1719],
#   'cui': 'C0733942',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0733942'},
#   '_input_hash': 528286105,
#   '_task_hash': -1353611354,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1682156195,
#   '_annotator_id': 'TLC-validation_v4-alon',
#   '_session_id': 'TLC-validation_v4-alon'},
#  '1017078619': {'text': 'Thread: [Nach Darm Op alles aus dem Gleichgewicht, kann das sein?]\nText: [Jeder chirurgische Eingriff hat Auswirkungen auf den Organismus. Dass Deine allgemeine Anfälligkeit mit der Darm-OP zusammenhängt, wage ich zu bezweifeln. Bei mir ist genau das Gegenteil passiert: Seitdem mir vor 14 Jahren der gesamte Dickdarm entfernt wurde, habe ich kaum mehr Erkältungen. Auch meine therapieresistente chronisch-eitrige Broncho-Sinusitis ist seitdem verschwunden.\nDas mit dem Essen ist für mich schon eher nachvollziehbar, mitunter funktioniert auch die Verdauung nicht mehr ganz einwandfrei. Das wiederum hängt davon ab, welches Teilstück des Dickdarms und vor allem auch, wie viel entfernt wurde.]\n',
#   'spans': [{'start': 297, 'end': 326, 'label': 'Mention'}],
#   'html': '<b>C0192871</b>: Totale Kolektomie: Chirurgische Entfernung des gesamten Dickdarms.',
#   'annotation_ids': [7068],
#   'cui': 'C0192871',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0192871'},
#   '_input_hash': 1017078619,
#   '_task_hash': -207963746,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1682156388,
#   '_annotator_id': 'TLC-validation_v4-alon',
#   '_session_id': 'TLC-validation_v4-alon'},
#  '-393490479': {'text': 'Thread: [salz im brot,macht es die nieren kaputt?!]\nText: [Hallo! Die Brotmenge von 500 Gramm / Tag erscheint mir auch sehr hoch. Das ist schon einseitige Ernährung und unabhängig vom Salz nicht gesund (Vitamine!). Zwischen den Salzen (Speisesalz, Meersalz, Himalayasalz usw.) gibt es chemisch keine Unterschiede. Dann liegst Du mit 6 Gramm Salz pro Tag ganz richtig! Versuche bitte mal das mit einer Briefwage abzuwiegen - das ist eine ganze Menge, sodass man mit dem Salzstreuer kaum so hoch kommt.\nEs gibt freilich auch die Ansicht, man bräuchte überhaupt kein Salz zu zuführen, selbst bei starkem Schwitzen. Das geht meines Erachtens von der veralteten Annahme aus, dass in Speisen schon zuviel Salz enthalten ist. Aber das war einmal, heute ist alles was Du käufst schon \\salzarm\\ oder ganz mit Ersatzstoffen. ]\n',
#   'spans': [{'start': 601, 'end': 610, 'label': 'Mention'}],
#   'html': '<b>C1561530</b>: Probetyp - Schweiß',
#   'annotation_ids': [6255,
#    6256,
#    5449,
#    5450,
#    873,
#    874,
#    875,
#    1227,
#    5780,
#    5284,
#    4507,
#    4508,
#    2132,
#    2133,
#    2134],
#   'cui': 'C1561530',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C1561530'},
#   '_input_hash': -393490479,
#   '_task_hash': 1420673454,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1683810310,
#   '_annotator_id': 'TLC-validation_v4-selin',
#   '_session_id': 'TLC-validation_v4-selin'},
#  '-1908421494': {'text': 'Thread: [Nierenstein ohne OP entfernen]\nText: [Hallo, also wie das bei nur (einer) Niere ist weiß ich nicht.\nKlar das Risiko ist etwas größer, falls etwas schief läuft, aber genau deshalb wollte ich dir antworten.\nIch habe grad im Klinikum Dortmund Nord nach bösen Nierenstein- Koliken eine Schiene bekommen, Nierenstein wurde in die Niere zurückgeschubst, was in vielen Fällen passiert. Dann wurde er zweimal im Abstand von 2 Tagen mit Stoßwellen beschossen.\nbeim zweiten Mal mit Betäubung über die Vene, weil es nicht bzw. ( für mich nicht) auszuhalten war. Der Stein wurde dann zufriedenstellend zerlegt. Ich hatte weder Blutergüsse an der Niere, noch sonst ein Problem (bisher) bin seid wenigen Tagen aus dem KH entlassen und mein Eindruck bis jetzt ist, dass meine Niere zu keinem Zeitpunkt der Eingriffe im Krankenhaus in irgendeiner Gefahr gewesen ist. Mein Eindruck war sehr gut und das Personal hat alles zu jedem Zeitpunkt souverän im Griff gehabt ( war mein Eindruck) und man hat mich nie leiden oder warten lassen.\nIch habe jetzt wie gesagt noch die Schiene und die zertrümmerten Steinteile und werde mir überlegen das auch noch abschließend dort stationär fertig behandeln zu lassen, man kann es zwar natürlich ambulant machen lassen, aber wenn es möglich ist gehe ich wieder in diese Klinik, da war einfach alles perfekt so wie man es sich nur wünschen kann. Von wo kommst Du denn ? Sicher hat jede große Stadt eine solche Klinik ! ich weiß nicht ob man sich mit Deiner Diagnose einweisen lassen kann, bei mir war es der Notruf und der Krankenwagen und es war akut, aber ich denke schon das man sich einweisen lassen kann, aber das wissen bestimmt andere hier genauer als ich. Bestimmt sind Urologen mit kleiner Praxis auch gut, ich habe aber eben auch nur diese eine Erfahrung bis jetzt, weil es mein erster Nierenstein ist. Wenn man nur eine Niere hat...vielleicht besser auf Nummer sicher und in eine renommierte Klinik gehen !?\nLg]\n',
#   'spans': [{'start': 624, 'end': 648, 'label': 'Mention'}],
#   'html': '<b>C0475022</b>: Hämatom der Niere',
#   'annotation_ids': [1030],
#   'cui': 'C0475022',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0475022'},
#   '_input_hash': -1908421494,
#   '_task_hash': 1720339304,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1682156483,
#   '_annotator_id': 'TLC-validation_v4-alon',
#   '_session_id': 'TLC-validation_v4-alon'},
#  '-1430778723': {'text': 'Thread: [Niereninsuffizienz und Zeugungsfähigkeit?]\nText: [agnes hat recht, rauchen geht gar nicht. 90 % der Patienten auf meiner Dialyse-Station sind durch Diabetes oder Rauchen - oder besonders schlimm: die Kombination aus beidem! - zur Dialyse gekommen. Er handelt sich damit vor allem auch für später jede Menge Probleme ein. Z.B. wenn er mal einen Shunt (einen chirurgischen Zusammenschluss einer Arterie und einer Vene, meistens am Unterarm) für die Dialyse braucht oder wenn mal eine Nierentransplantation ansteht. Die neue Niere muss ja an die Arterien im Becken angeschlossen werden und wenn die vom Rauchen bereits total sklerotisch sind, dann geht das nicht.\nAn eurer Stelle würde ich mich auch nicht mit irgendwelchen Vermutungen abfinden. Die Ursache sollte schon genau abgeklärt werden. Seit wann hat er eigentlich die Niereninsuffizienz bzw. wann wurde sie festgestellt? Und wie war der Verlauf bisher, also wie stark hat sie sich in welchem Zeitraum verschlechtert?\nWarum nimmt er nur ab und zu ACE-Hemmer? Das ist eigentlich kein Bedarfsmedikament. agnes möge mich korrigieren, aber neue Studien belegen soweit ich weiß, dass eine Therapie mit ACE-Hemmern das Fortschreiten der Niereninsuffizienz verlangsamen kann. Außerdem sollte sein Blutdruck gut eingestellt sein, laut neuesten Studien gilt 120 / 80 für Patienten, die einer Risikogruppe angehören - bei uns gilt als Therapieziel 115 / 75.\nDas Gewicht passt schon. Er sollte vor allem noch darauf achten, immer viel zu trinken!\nAchja: Spermien einfrieren würde ich mal für überflüssig halten. Bei der mäßigen Niereninsuffizienz dürfte es wie gesagt eigentlich jetzt gar kein Problem geben und bis die mal so weit fortgeschritten ist, dass sie dahingehend Probleme macht, könnt ihr ganz locker noch 4 bis 5 Kinder zeugen. ]\n',
#   'spans': [{'start': 1507, 'end': 1526, 'label': 'Mention'}],
#   'html': '<b>C0519952</b>: Kryokonservierung von Spermatozoen',
#   'annotation_ids': [1682],
#   'cui': 'C0519952',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0519952'},
#   '_input_hash': -1430778723,
#   '_task_hash': -151623077,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1682156622,
#   '_annotator_id': 'TLC-validation_v4-alon',
#   '_session_id': 'TLC-validation_v4-alon'},
#  '403648989': {'text': 'Thread: [Darmprobleme trotz vieler Untersuchungen nicht geklärt, jetzt auch Frau und Kind betroffen?!]\nText: [Ich habe seit einigen Wochen Probleme mit meinem Darm. Eigentlich geht es nur darum, dass ich ungefähr ab Mittags starken Druck um den Bauchnabel und häufiger nach links ausstrahlend verspüre, was dann bis in die Nacht geht. Es scheint, dass es sich vor allem um sehr viel Luft geht, die dort jeden Tag ab ca. Mittags gebildet wird. Das Ganz geht einher mit vielen Blähungen. Der Stuhlgang ist fast immer geformt, wenn auch sehr dünn. Gestern allerdings hatte ich dunklen Durchfall. Während meiner Beschwerden hatte ich auch schon sichtbares Blut im Stuhl, aber das lag laut Arzt an einer kleinen Entzündung im Rektum, wofür ich Medikamente bekam. Das Blut ist auch längst wieder weg, nur diese täglichen Probleme um den Bauchnabel herum sind immer da. Selbst Darmspiegelung, Magenspiegelung, Proktoskopie, MRT Sellink, Ultraschall brachten keine Ergebnisse. Die Blutwerte sind super, ein Calprotectin Wert im Stuhl lag erhöht bei über 500 und auch die Untersuchung auf Pilze war negativ.\nZur Zeit versuche ich, anhand von Nahrungsmitteln zu prüfen, ob eine Unverträglichkeit vorliegt. Bisher war es jeden Tag gleich, egal was ich gegessen habe, immer ab Mittags Druck, Blähungen und ein Völlegefühl im genannten Bereich, mittig und links oberhalb und unterhalb des Bauchnabels.\nWas mich nun völlig verwirrt. Meine Frau hatte heute auch sichtbares Blut im Stuhl, (ihre Tage sind noch entfernt), allerdings ohne weitere Symptome und mein Kind hat seit gestern Bauchweh mit Durchfall. Alles Zufall oder reden wir hier vielleicht von etwas ganz anderem? Vielleicht habt Ihr ja noch eine Idee, die Ärzte halten mich mittlerweile schon für einen Hypochonder, obwohl die Beschwerden eindeutig da sind.]\n',
#   'spans': [{'start': 707, 'end': 727, 'label': 'Mention'}],
#   'html': '<b>C0033246</b>: Proktitis: ENTZÜNDUNG des MUCOUS MEMBRANE des RECTUM, des distalen Endes des Dickdarms (INTESTINE, LARGE).',
#   'annotation_ids': [4890],
#   'cui': 'C0033246',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0033246'},
#   '_input_hash': 403648989,
#   '_task_hash': -282727463,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1682156650,
#   '_annotator_id': 'TLC-validation_v4-alon',
#   '_session_id': 'TLC-validation_v4-alon'},
#  '1536609858': {'text': 'Thread: [Blinddarm - langes \\Leiden\\]\nText: [Hallo zusammen,\nIch habe seit einiger Zeit, nun gut zwei Monate, folgendes Problem:\nIch hab immer wieder mal kurz, meines Eindrucks nach genau dann, wenn Stuhl das Ileum passiert, Schmerzen.\nHausarzt und Gastroenterologe vermuteten zuerst eine Blinddarmreizung oder Entzündung. Behandelt wurde zunächst, ohne wirkliche Besserung, mit Antibiotika.\nAuf dem Ultraschall war nichts zu erkennen. Bei einer vorsichtshalber stattgefundenen Darmspiegelung konnte der G.E. nichts erkennen, was auffällig wäre: Befund OK.\nJetzt aktuell treten die Schmerzen wieder stärker auf:\nImmer mal wieder, sporadisch, kurzer (5-20 Sskunden) stechender Schmerz auf Höhe Darmbein. Manchmal seitlich, manchmal zwischen Bauchnabel und Darmbein, auf jeden Fall im unteren rechten Viertel des Bauches umherwandernd.\nDer Schmerz ist nicht kontinuierlich, allerdings habe ich leichte Panik dadurch, dass mein Hausarzt meinte, es gäbe Fälle in denen sich eine Blinddarmentzündung mit Durchbruch so kaschiert hatte.\nKann es das sein? Woran würdet ihr spontan noch denken?\nIch habe einen Reizdarm und daher ohnehin schon nicht selten Verdaaungsprobleme, aber seit einigen Tagen noch zusätzlich viel Luft im Bauch.\nKann das ein durchbrechender Wurmfortsatz sein? Besteht Grund zur Sorge?\nWürde ich einen Blinddarmdurchbruch oder eine starke Entzündung rechtzeitig bemerken oder sollte ich vorsichtshalber das KH aufsuchen?\nVielen Dank vorab.]\n',
#   'spans': [{'start': 693, 'end': 701, 'label': 'Mention'}],
#   'html': '<b>C0020889</b>: Knochenstruktur des Darmbeins: Der größte der drei Knochen, aus denen die beiden Hälften des Beckengürtels bestehen.',
#   'annotation_ids': [5516, 5517, 6781],
#   'cui': 'C0020889',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0020889'},
#   '_input_hash': 1536609858,
#   '_task_hash': -1369033871,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1682158056,
#   '_annotator_id': 'TLC-validation_v4-alon',
#   '_session_id': 'TLC-validation_v4-alon'},
#  '1480243446': {'text': 'Thread: [Blinddarm - langes \\Leiden\\]\nText: [Hallo zusammen,\nIch habe seit einiger Zeit, nun gut zwei Monate, folgendes Problem:\nIch hab immer wieder mal kurz, meines Eindrucks nach genau dann, wenn Stuhl das Ileum passiert, Schmerzen.\nHausarzt und Gastroenterologe vermuteten zuerst eine Blinddarmreizung oder Entzündung. Behandelt wurde zunächst, ohne wirkliche Besserung, mit Antibiotika.\nAuf dem Ultraschall war nichts zu erkennen. Bei einer vorsichtshalber stattgefundenen Darmspiegelung konnte der G.E. nichts erkennen, was auffällig wäre: Befund OK.\nJetzt aktuell treten die Schmerzen wieder stärker auf:\nImmer mal wieder, sporadisch, kurzer (5-20 Sskunden) stechender Schmerz auf Höhe Darmbein. Manchmal seitlich, manchmal zwischen Bauchnabel und Darmbein, auf jeden Fall im unteren rechten Viertel des Bauches umherwandernd.\nDer Schmerz ist nicht kontinuierlich, allerdings habe ich leichte Panik dadurch, dass mein Hausarzt meinte, es gäbe Fälle in denen sich eine Blinddarmentzündung mit Durchbruch so kaschiert hatte.\nKann es das sein? Woran würdet ihr spontan noch denken?\nIch habe einen Reizdarm und daher ohnehin schon nicht selten Verdaaungsprobleme, aber seit einigen Tagen noch zusätzlich viel Luft im Bauch.\nKann das ein durchbrechender Wurmfortsatz sein? Besteht Grund zur Sorge?\nWürde ich einen Blinddarmdurchbruch oder eine starke Entzündung rechtzeitig bemerken oder sollte ich vorsichtshalber das KH aufsuchen?\nVielen Dank vorab.]\n',
#   'spans': [{'start': 838, 'end': 870, 'label': 'Mention'}],
#   'html': '<b>C1282310</b>: Intermittierende Schmerzen',
#   'annotation_ids': [5523],
#   'cui': 'C1282310',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C1282310'},
#   '_input_hash': 1480243446,
#   '_task_hash': 79808020,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1682158266,
#   '_annotator_id': 'TLC-validation_v4-alon',
#   '_session_id': 'TLC-validation_v4-alon'},
#  '1628718292': {'text': 'Thread: [Andauernd Blähungen, hören nicht auf]\nText: [Ich melde mich mal wieder zurück. Hatte wenig Zeit und habe versucht, nicht an das Thema zu denken, mich nicht damit zu befassen. Eure Tips habe ich mir zu Herzen genommen, Kamillan habe ich mir auch besorgt, Flohsamenschalen sind bestellt.\nWas soll ich sagen. Allmählich bekomme ich es mit Angst zutun. Blähbauch ist immer noch da, jedoch ist mein Bauch nie \\dick\\, eher wurde ich gefragt, ob ich abgenommen hätte. Aber für mich fühlt es sich aufgebläht an, das einfach was nicht normal ist. Merke ich dann auch beim Stuhlgang, wieviel Luft wirklich rauskommt.\nDurchfall, weicher Stuhl, gelber Stuhl, das ist komplett weg, alles normal wieder.  Blähbauch wie gesagt geblieben, komischerweise kommt es nach ein paar Stunden nach dem Aufstehen. Wenn ich was esse, wird es komischerweise besser ?! Wie wenn das Essen die Blähungen wegdrückt ohne das Luft entweicht, lol. Jedenfalls ist es dann für 2 Stunden oder 3 fast weg.\nHinzugekommen ist, dass ich circa 3 Fingerbreit, etwas links versetzt ( von mir aus gesehen) über dem Bauchnabel Schmerzen habe.\nImmer wieder mal, wobei man es noch nicht als Schmerz bezeichnen kann. Eher so ein Druckgefühl, keine Ahnung. Ganz komisch. Meist so 2-3 Stunden nach dem Essen , nicht permanent.\nWarte jetzt noch 1-1,5 Wochen ab und wenn sich das nicht normalisiert muss ich wohl mal zum Arzt...]\n',
#   'spans': [{'start': 1070, 'end': 1089, 'label': 'Mention'}],
#   'html': '<b>C0442196</b>: Supraumbilikal',
#   'annotation_ids': [4882],
#   'cui': 'C0442196',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0442196'},
#   '_input_hash': 1628718292,
#   '_task_hash': -2128637071,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1682158416,
#   '_annotator_id': 'TLC-validation_v4-alon',
#   '_session_id': 'TLC-validation_v4-alon'},
#  '560172144': {'text': 'Thread: [Ständig Heißhunger, übelkeit, Lipase erhöht]\nText: [Dachte ich mir bereits, bei jungen, großen und schlanken Männern kann in äußerst extrem seltenen Fällen ein dann meist gutartiger Tumor in der BSD sein, der Insulin produziert. Aber wie gesagt EXTREM selten und eher seeehr unwahrscheinlich. Eine Diagnostik der BSD ist sicherlich ratsam.]\n',
#   'spans': [{'start': 180, 'end': 196, 'label': 'Mention'}],
#   'html': '<b>C0086692</b>: Gutartiges Neoplasma: Ein Neoplasma, das durch das Fehlen morphologischer Merkmale gekennzeichnet ist, die mit Malignität in Verbindung gebracht werden (schwere zytologische Atypien, Tumorzellnekrose und hohe Mitoserate). Gutartige Neoplasmen bleiben auf den ursprünglichen Wachstumsort beschränkt und metastasieren nicht an anderen anatomischen Stellen.',
#   'annotation_ids': [5982],
#   'cui': 'C0086692',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0086692'},
#   '_input_hash': 560172144,
#   '_task_hash': 429146942,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1683811313,
#   '_annotator_id': 'TLC-validation_v4-selin',
#   '_session_id': 'TLC-validation_v4-selin'},
#  '-1082955093': {'text': 'Thread: [Harnleiterschiene, werden die Schmerzen besser?]\nText: [Danke für deine Antwort. echt? das ist ja krass, nach 2-3 Tagen schon? Der Arzt sagte mir was was mindestens zwei Wochen, idealerweise 5 Wochen, bevor überhaupt reingeschaut wurde. Zu enge Harnleiter glaube nicht, denn es sind schon Steine 5-7 mm rausgekommen ohne Koliken. Der Termin wurde auch nicht vereinbart sondern mir einfach hingeknallt, obwohl der Arzt wußte dass ich es kaum aushalten werde mit der Schiene.\nDie Schmerzen im Unterleib gehen nun aber die Niere tut mir weh und der Urin ist immer noch rot, sollte ich lieber nochmal kontrollieren lassen?\nIch vermute aber dass es so lange ist, weil die ja auch die Steine in der Niere gleich mit wegmachen wollen. Da sind zwei 3 u. 4 mm große Steine, von denen ich bisher nichts gemerkt habe.]\n',
#   'spans': [{'start': 487, 'end': 509, 'label': 'Mention'}],
#   'html': '<b>C0000737</b>: Unterleibsschmerzen: Gefühl des Unbehagens, der Bedrängnis oder des Schmerzes in der Bauchgegend.',
#   'annotation_ids': [1996],
#   'cui': 'C0000737',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0000737'},
#   '_input_hash': -1082955093,
#   '_task_hash': 1370028589,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1682158548,
#   '_annotator_id': 'TLC-validation_v4-alon',
#   '_session_id': 'TLC-validation_v4-alon'},
#  '598323043': {'text': 'Thread: [Ct Niere Urographie, da suspekter Befund]\nText: [Moin, mein Mann, 77 Jahre alt, hat eine Überweisung zum CT wegen Tumorverdachts auf Grund eines suspekten Befundes bei einer Kontrastmitteluntersuchung bekommen, dies steht so auf der Überweisung. Der behandelnde Urologe hat keine anderen möglichen Befunde genannt. Ich mache mir natürlich große Sorgen und möchte nun gerne wissen, ob ein suspekter Befund zwangläufig einen Tumor beinhaltet, oder ob er auch andere Diagnosen möglich sind. Wenn ja, wundere ich mich, dass der Urologe diese nicht nennt um uns dadurch zumindest bis zur Untersuchung etwas zu beruhigen. Die Werte für Harnsäure, Harnstoff und Kreatin sind im Normbereich, Blut ist im Urin mit einem handelsüblich Teststreifen zur Zeit nicht nachweisbar. Vor ca. einem halben Jahr hatte mein Mann eine äußerst heftige Blasenentzündung mit hohem Fieber und Blut im Urin. Eine Nierenbeckenentzündung soll nach Auskunft des Urologen damals nicht vorgelegen haben. Der jetzige suspekte Befund ist eher ein Zufallsbefund, da der Urologe meine Mann regelmäßig zur Kontrolle bestellt, warum auch immer.\nVielen Dank für eine Antwort.\nislandia]\n',
#   'spans': [{'start': 183, 'end': 197, 'label': 'Mention'}],
#   'html': '<b>C0009924</b>: Kontrastmittel: Substanzen, die zur besseren Sichtbarmachung von Geweben verwendet werden.',
#   'annotation_ids': [2191, 2582, 2934],
#   'cui': 'C0009924',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0009924'},
#   '_input_hash': 598323043,
#   '_task_hash': -771901674,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1682158600,
#   '_annotator_id': 'TLC-validation_v4-alon',
#   '_session_id': 'TLC-validation_v4-alon'},
#  '1228813267': {'text': 'Thread: [Ct Niere Urographie, da suspekter Befund]\nText: [Moin, mein Mann, 77 Jahre alt, hat eine Überweisung zum CT wegen Tumorverdachts auf Grund eines suspekten Befundes bei einer Kontrastmitteluntersuchung bekommen, dies steht so auf der Überweisung. Der behandelnde Urologe hat keine anderen möglichen Befunde genannt. Ich mache mir natürlich große Sorgen und möchte nun gerne wissen, ob ein suspekter Befund zwangläufig einen Tumor beinhaltet, oder ob er auch andere Diagnosen möglich sind. Wenn ja, wundere ich mich, dass der Urologe diese nicht nennt um uns dadurch zumindest bis zur Untersuchung etwas zu beruhigen. Die Werte für Harnsäure, Harnstoff und Kreatin sind im Normbereich, Blut ist im Urin mit einem handelsüblich Teststreifen zur Zeit nicht nachweisbar. Vor ca. einem halben Jahr hatte mein Mann eine äußerst heftige Blasenentzündung mit hohem Fieber und Blut im Urin. Eine Nierenbeckenentzündung soll nach Auskunft des Urologen damals nicht vorgelegen haben. Der jetzige suspekte Befund ist eher ein Zufallsbefund, da der Urologe meine Mann regelmäßig zur Kontrolle bestellt, warum auch immer.\nVielen Dank für eine Antwort.\nislandia]\n',
#   'spans': [{'start': 639, 'end': 648, 'label': 'Mention'}],
#   'html': '<b>C0202239</b>: Harnsäuremessung (Verfahren): Eine quantitative Messung der in einer Probe vorhandenen Uratmenge.',
#   'annotation_ids': [2192],
#   'cui': 'C0202239',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0202239'},
#   '_input_hash': 1228813267,
#   '_task_hash': 1781184976,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1682158641,
#   '_annotator_id': 'TLC-validation_v4-alon',
#   '_session_id': 'TLC-validation_v4-alon'},
#  '1984156682': {'text': 'Thread: [Wasserklarer Urin und dumpfes ziehen]\nText: [Zunächst einmal sollte eine einfache Blasenentzündung ausgeschlossen werden - die kann auch ohne Schmerzen unter Umständen verlaufen. Eine solche wäre jedenfalls eine naheliegende Erklärung für deine akute Inkontinenzoroblematik - die kann nicht direkt etwas mit den Nieren zu tun haben.\nNun zu dem glasklaren Urin und der erhöhten Ausscheidung. Ein Diabetes insipidus käme nur dann in Betracht, wenn du auch tatsächlich deutlich mehr trinkst.\nDa du aber kein erhöhtes Durstgefühl zu haben scheinst und nicht mehr trinkst, sollte der HA wenigstens Basistests der Nierenfunktion untersuchen lassen, um dich dann ggf an einen Nephrologen zu überweisen.\nDas anfängliche Stadium der chronischen Niereninsuffizienz macht sich nämlich anders bemerkbar, als akute Niereninsuffizienz oder als das fortgeschrittene Stadium der chron. Niereninsuffizienz: es äußert sich in einer verminderten Fähigkeit der Nieren, den Urin zu konzentrieren. Daher erscheint der Urin sehr klar, wie Wasser, und der Patient bemerkt, dass er größere Urinmengen ausscheidet als zuvor - bei gleichem Trinkverhalten.\nSpreche doch erst einmal deinen HA darauf an, dass er Kreatinin/ die eGFR im Blut und die Kreatinin Clearance im 24h Urin bestimmen lässt.\nZudem könnte wegen der Inkontinenz eine Urodynamik durchgeführt werden um zu sehen, ob eine Funktionsstörung der Blase und/oder der Schließmuskel vorliegt. Eine Funktionsstörung der Blase kann auch manchmal mit einem Rückstau in die Nieren vergessellschaftet sein, was über längere Zeit zu einem sekundären Nierenschaden führen kann.]\n',
#   'spans': [{'start': 1494, 'end': 1516, 'label': 'Mention'}],
#   'html': '<b>C0042580</b>: Vesiko-ureteraler Reflux: Rückfluss von Urin aus der Harnblase in den Harnleiter (URETER). Dies ist häufig auf eine Inkompetenz der vesikoureteralen Klappe zurückzuführen.',
#   'annotation_ids': [1760],
#   'cui': 'C0042580',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0042580'},
#   '_input_hash': 1984156682,
#   '_task_hash': -251130264,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1682158675,
#   '_annotator_id': 'TLC-validation_v4-alon',
#   '_session_id': 'TLC-validation_v4-alon'},
#  '383937688': {'text': 'Thread: [Slow transit obstipation: OP ja oder nein?]\nText: [Hallo bin 25Jahre und habe eine slow transit obstipation. Ich wurde sehr lange, was viele von euch kennen als simulant abgestempelt.\nBei mir wurden nun endlich mal nähere untersuchungen durchgeführt wie die transitzeit (106std) und es wurde gesehen, das mein quercolon im kleinen becken hängt und der absteigende darm sowie der enddarm zulang sind. Jetzt bin ich zurzeit in einem Kh in behandlung und die Chirurgen würden operieren und die Gastroenterologen sind dagegen. ich bin gerade ziemlich verzweifelt weil ich nicht weiß was ich machen soll. Achso im quercolon und im absteigenden darm sind kaum muskeln vorhanden.\nIch wäre dankbar für jeden rat.\nlg]\n',
#   'spans': [{'start': 361, 'end': 377, 'label': 'Mention'}],
#   'html': '<b>C0227389</b>: Absteigender Dickdarm: Der Abschnitt des GROSSEN DARMES zwischen dem TRANSVERSE COLON und dem SIGMOID COLON.',
#   'annotation_ids': [6294],
#   'cui': 'C0227389',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0227389'},
#   '_input_hash': 383937688,
#   '_task_hash': -1605302591,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1682158944,
#   '_annotator_id': 'TLC-validation_v4-alon',
#   '_session_id': 'TLC-validation_v4-alon'},
#  '-639862904': {'text': 'Thread: [Histamin Intoleranz, durchlässiger Darm]\nText: [Also ich kenne auch Ärzte, die besser Tischler geworden wären, aber auch welche, die das Thema mit Histam und Darm durchaus ernst nehmen. Mein klassisch schulmedizinischer HNO Arzt ist so ein Beispiel, der ist fest davon überzeugt (Leaky Gut, Weizen und so).\nIch wäre immer sehr vorsichtig mit der Zuweisung der absoluten Wahrheit. Aufgeschlossen in jede Richtung (also auch die, dass es sehr warhscheinlich halt genauso sein könnte, mit dem Darm etc) ist mit Sicherheit richtig.\nDass die Schulmedizin das Thema \\Darmflora\\, speziell nach Antibiotika-Gabe, komplett ignoriert, ist allerdings unzutreffend. Da hast Du dann punktuell sehr schlechte eigene Erfahrungen gemacht.\nLetztlich sehe ich da den Profit und die Lobbygruppen als Problem - eine ursächliche Heilung von Beschwerden, die ohne gewinnbringende Medizinprodukte erfolgt (Darm heilen mit Ernährungsumstellung und Brottrunk..), interessiert einfach niemanden, der da Macht und Einfluß hätte, und insofern passiert da auch nix. Antihistaminika verkaufen ist gewinnträchtiger.\nIrgendwie muss man allerdings auch kein Arzt oder Heilpraktiker oder überhaupt besonders intelligent sein um zu erkennen dass jahre-, gar jahrzehntelange Fehlernährung ihre Folge hat. Der Körper ist halt eine komplexe Chemiefabrik und der Zustand ist wesentlich davon abhängig, was man vorne reinschüttet. Schädliche Dinge werden ihrem Namen dann halt auf Dauer gerecht und schaden.]\n',
#   'spans': [{'start': 289, 'end': 298, 'label': 'Mention'}],
#   'html': '<b>C5578085</b>: Undichter Darm',
#   'annotation_ids': [6008, 5320, 7383],
#   'cui': 'C5578085',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C5578085'},
#   '_input_hash': -639862904,
#   '_task_hash': 678248831,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1682159080,
#   '_annotator_id': 'TLC-validation_v4-alon',
#   '_session_id': 'TLC-validation_v4-alon'},
#  '-1952359105': {'text': 'Thread: [Blut im Urin durch 3 Nierenzysten ?]\nText: [Hallo.\n2015 wurde bei mir unsichtbares Blut entdeckt,dies wurde aber nicht weiter verfolgt und es hiess ich hätte eine harmlose nierenzyste mit 1,5 cm.\nOktober 2016 hatte sichtbares blut im urin und 2 Tage später heftige flankenschmerzen links,es wurde erst im CT gesehen das ein 2mm Stein im Halbleiter ist,und das CT hat ergeben das ich an der linken niere 3 harmlose zysten habe.\nEin NMP22 Test und eine Blasenspiegelung hat auch nichts ergeben.\nLetzte Woche lag ich mit einem magen darm Infekt mit leichtem fieber im Bett,1 Tag später nach Medikamenten Einnahme paracetamol,buscopan Biathlon und vomex hatte ich wieder sichtbares blut im urin mit einem ziehen in der linken nierengegend wo die 3 zysten sind,es waren aber keine Kolik sondern ein leichtes ziehen.\nJetzt zu meiner Frage.\nKann blut im urin von den 3 zysten die ich an der linken niere hab kommen ?\nBin Männlich und 33 Jahre alt]\n',
#   'spans': [{'start': 555, 'end': 570, 'label': 'Mention'}],
#   'html': '<b>C4324354</b>: Subfebrile',
#   'annotation_ids': [3839],
#   'cui': 'C4324354',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C4324354'},
#   '_input_hash': -1952359105,
#   '_task_hash': -532888833,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1683812228,
#   '_annotator_id': 'TLC-validation_v4-selin',
#   '_session_id': 'TLC-validation_v4-selin'},
#  '1541538160': {'text': 'Thread: [An alle, die es mit der Blase bzw. mit den Nieren haben]\nText: [Zu den ständigen Blasenentzündungen:\n1. viel trinken, keine Zitrus-Fruchtsäfte, keinen Kaffee\n2. häufig zur Toilette (alle 1-2 Stunden), das hilft auch gegen den Nierenstau, bei leerer    Blase fließt die Niere besser ab (bei mir jedenfalls).\n3. keine kalte Füße bekommen!\n4. das homöopathische Mittel Cantharis D4 hilft auch ganz gut bei schmerzhafter Blasenentzündung. Das sind süße Kügelchen, die man bei Bedarf nimmt (6-10 Stück). Einfach unter der Zunge langsam zergehen lassen. Gibts nur in der Apotheke ca. \\u20ac 8,00.\nIch hoffe Dir damit ein wenig weitergeholfen zu haben - weiterhin alles Gute!!!:-)]\n',
#   'spans': [{'start': 235, 'end': 245, 'label': 'Mention'}],
#   'html': '<b>C0178879</b>: Obstruktion der ableitenden Harnwege: Blockierung des normalen Abflusses des Harnwegsinhalts.',
#   'annotation_ids': [4571,
#    1018,
#    800,
#    3517,
#    3591,
#    4013,
#    4547,
#    4548,
#    2803,
#    2804,
#    3446,
#    1218,
#    2017,
#    2022,
#    1073,
#    1074,
#    34,
#    35,
#    38,
#    3068,
#    2385,
#    2774,
#    957],
#   'cui': 'C0178879',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0178879'},
#   '_input_hash': 1541538160,
#   '_task_hash': -1473160061,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1683997914,
#   '_annotator_id': 'TLC-validation_v4-selin',
#   '_session_id': 'TLC-validation_v4-selin'},
#  '201451701': {'text': 'Thread: [Blasenentzündung, jetzt Schmerzen im Bereich der Nieren]\nText: [Dein urologe soll mal eine Blasenspiegelung machen. Es gibt nicht-bakterielle Blasenentzündungen, wo glaub ich die Blasenschleimhaut gereizt/entzündet ist. Das kann man bei einer Spiegelung sehen.\nDie Nieren waren ok im Ultraschall?]\n',
#   'spans': [{'start': 133, 'end': 169, 'label': 'Mention'}],
#   'html': '<b>C0282488</b>: Interstitielle Blasenentzündung: Ein Zustand mit wiederkehrenden Beschwerden oder Schmerzen in der Harnblase und der umgebenden Beckenregion ohne erkennbare Erkrankung. Die Schwere der Schmerzen bei interstitieller Zystitis ist sehr unterschiedlich und wird oft von einer erhöhten Häufigkeit und einem erhöhten Harndrang begleitet.',
#   'annotation_ids': [4289],
#   'cui': 'C0282488',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0282488'},
#   '_input_hash': 201451701,
#   '_task_hash': 2035024978,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1682159611,
#   '_annotator_id': 'TLC-validation_v4-alon',
#   '_session_id': 'TLC-validation_v4-alon'},
# ...
#  '167102995': {'text': "Thread: [Zucken (Stolpern) im Oberbauch]\nText: [Hallo zusammen,\nwas für eine Freude zu merken, dass man mit seinen Problemen nicht allein ist. Bei mir treten seit ca. 3 Wochen die gleichen Symptome auf, ich habe teilweise so Zuckungen unter dem Brustbein, gefühlt einen zeitweisen sehr hohen Blutdruck (ob er es wirklich ist weiß ich nicht), und solche Extrasystolen.\nDas ganze fing bei mir an, als ich sehr sehr viele Antibiotika schlucken musste aufgrund einer starken Grippe. Meinem Magen und Darm hat das Ganze gar nicht gefallen, hatte wochenlang durchfall, teilweise ganz grün. Mein Darm hat sich erholt, der Magen nicht. Habe ständig so eine Art Druckgefühl im Hals, wie wenn einem ein Klos da hinten stecken bleibt, gleichzeitig drückt auch mein Magen..teilweise kommt noch starkes Sodbrennen dazu.\nSeit ich diese Magenprobleme habe, ging es auch mit den HRS und den ES los. Diese kommen teilweise wie aus dem nichts, jedoch habe ich festgestellt, dass diese nach dem Aufstehen nicht auftreten, dafür aber umso häufiger im Übergang zwischen Stress und abendlicher Ruhephase. Ebenso nach dem Essen und in schräger Körperlage, sprich wenn man so halb gegen ein großes Kissen lehnt. Ich muss auch ständig Rülpsen, auch wenn ich nichts getrunken habe, was mich doch sehr verwirrt.\nIch habe ebenfalls gelesen, dass jemand mit diesen Symptomen an Nesselsucht leidet. Das tue ich auch, seit ich denken kann muss ich täglich Cetirizin nehmen, um der Krankheit einigermaßen Herr zu werden, andernfalls habe ich extremsten Ausschlag am ganzen Körper.

#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1687772631,
#   '_annotator_id': 'TLC-validation-second-round-alon',
#   '_session_id': 'TLC-validation-second-round-alon'},
#  '1966492551': {'text': 'Thread: [Erosive Gastritis, Refluxösophagitis,Pilz im Mund, Diverse Symptome seid 1,5 Jahren]\nText: [Die Ursache wurde nie gesucht bzw mir haben die Ärzte nur gesagt Omeprazol und das wars. Trinke keinen Alkohol, Nehme keine schädigende Medikamente Schmerzmittel seid mindestens 3 Jahren nicht eine genommen. nehme jetzt seid 3 Monaten Omeprazol 40mg]\n',
#   'spans': [{'start': 105, 'end': 112, 'label': 'Mention'}],
#   'html': '<b>C0032930</b>: Niederschlagende Faktoren: Faktoren, die mit dem endgültigen Ausbruch einer Krankheit, eines Unfalls, einer Verhaltensreaktion oder einer Handlung zusammenhängen. Wenn mehrere Faktoren beteiligt sind, ist in der Regel ein Faktor wichtiger oder offensichtlicher als andere, und einer kann oft als "notwendig" angesehen werden. Beispiele hierfür sind die Exposition gegenüber einer bestimmten Krankheit, die Menge oder das Ausmaß eines infektiösen Organismus, einer Droge oder einer schädlichen Substanz usw.',
#   'annotation_ids': [7158, 7304],
#   'cui': 'C0032930',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0032930'},
#   '_input_hash': 1966492551,
#   '_task_hash': 319361226,
#   '_view_id': 'blocks',
#   'answer': 'reject',
#   '_timestamp': 1687772634,
#   '_annotator_id': 'TLC-validation-second-round-alon',
#   '_session_id': 'TLC-validation-second-round-alon'},
#  '5270799': {'text': 'Thread: [Niere]\nText: [Hallo!\nSeit Freitag habe ich einen Ferienjob. Am Freitagnachmittag hatte eine Arbeitskollegin die ganze Zeit einen Ventilator eingestellt.\nBereits während dem Arbeiten bemerkte ich ein Ziehen in der Nierengegend, dachte mir aber nichts dabei, weil es für mich normal ist, nachdem ich einen Tag lang stehen musste, etwas Rückenschmerzen zu bekommen. (Sonst sitze ich ja meistens nur..)\nDoch bereits am Abend wurde dieses Ziehen stärker, es fühlt sich wie ein starker Muskelkater an.\nBauchfrei war ich auch nicht, ich hatte eigendlich ein genug langes T-Shirt an.\nWas kann ich machen, dass dieses Ziehen so schnell wie möglich wieder weg geht?]\n',
#   'spans': [{'start': 489, 'end': 500, 'label': 'Mention'}],
#   'html': '<b>C0427008</b>: Steifigkeit',
#   'annotation_ids': [619],
#   'cui': 'C0231528',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0427008'},
#   '_input_hash': 5270799,
#   '_task_hash': 1493848769,
#   '_view_id': 'blocks',
#   'answer': 'ignore',
#   '_timestamp': 1687772682,
#   '_annotator_id': 'TLC-validation-second-round-alon',
#   '_session_id': 'TLC-validation-second-round-alon'},
#  '-988021557': {'text': 'Thread: [Gastritis? Bin am verzweifeln ...]\nText: [Hallo liebe Community,\nich bin langsam echt am verzweifeln und weiß nicht mehr weiter \nIch versuche mich kurz zu fassen damit dies nicht so ein endloser Text wird.\nAnfangen hat alles letztes Jahr im Juni wo ich in den Urlaub gefahren bin. Vor der Abreise musste ich noch direkt auf einer Tankstelle halten da ich plötzlich starke Bauchschmerzen bekam. Bin einige Zeit am Topf gesessen, hatte aber \\nur\\ normalen Stuhlgang. Die Magenschmerzen hielten eine ganze Zeit lang an, besonder nachdem ich gegessen habe wurde es schlimmer.\nZurück vom Urlaub suchte ich meine HA auf und schilderte mein Problem. Vermutlich Gastritis und bekam Pantoprazol verschrieben. Binnen kurzer Zeit wurde es wesentlich besser.\nSeither werde ich aber immer wieder mal von Bauchschmerzen geplagt nach dem Essen. Nicht jedes mal, aber immer wieder. Manchmal ging es auch ein ganzes Monat gut.\nSeit nun ca 1 Monat wurde es drastisch schlechter. Hatte z.T. auch nüchtern schmerzen und die Säureblocker halfen diesmal auch nichts. Eine Magenspiegelung musste her! Vor 3 Wochen wurde dies durchgeführt und eine leichte chronische Antrumgastritis (vermutlich Typ-C lt Internisten) festgestellt. Helicobacter wurde ausgeschlossen. Blutwerte soweit auch alle in Ordnung.\nIch hatte verschiedenste Dinge bereits probiert - natürlich die PPI (die nicht mehr helfen), einen Zeitraum lang nur Schonkost, 1 Woche Kokos+Oregano-ÖL (Noch vor der Spiegelung da hier noch Helicobacter im Raum stand), Heilerde.\nDerzeit nehme ich nur noch Bentonit, Flohsamenschalen und trinke Käsepappel bzw Kamillenblüten-Tee.\nSeit gestern Abend ist es sehr extrem. Hatte kaum Beschwerden den Nachmittag über und auch nach dem Abendessen nicht. Da dachte ich mir ich kann einen Schokoriegel riskieren. Seither sehr starke brennende und stechende Bauchschmerzen. Mittlerweile geht mir das auch so an die Substanz, dass ich manchmal einfach weine weil ich glaube, dass dies nie aufhören wird ...\nWodurch die Gastritis ausgelöst wurde kann ich mir schon vorstellen - hatte extrem viel Stress im letztem Jahr und ernährte mich ... sehr dumm \n Täglich Energydrinks, oft mal fettiges Essen etc\nSo komme ich zu meinen Fragen - kann dies wirklich noch eine Gastritis sein? Kann diese permanente zum Teil sehr starke Schmerzen hervorrufen? Kann mich ein Schokoriegel so weit zurückwerfen oder das ganze so stark verschlimmern damit ich praktisch wieder bei 0 beginne?\nIm Moment habe ich noch bis 1.8 Urlaub und etwas Zeit um mich zu erhohlen. Danach geht es in eine neue Arbeit und möchte gerne bis dahin halbwegs fit sein.\nIch bin über jede Antwort von euch sehr dankbar.\nlieben Gruß\nPhil]\n',
#   'spans': [{'start': 823, 'end': 837, 'label': 'Mention'}],
#   'html': '<b>C0376674</b>: Postprandiale Phase: Die Zeitspanne nach einer Mahlzeit oder Nahrungsaufnahme.',
#   'annotation_ids': [6672, 6075, 5225, 7089],
#   'cui': 'C0376674',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0376674'},
#   '_input_hash': -988021557,
#   '_task_hash': -161953957,
#   '_view_id': 'blocks',
#   'answer': 'reject',
#   '_timestamp': 1687772717,
#   '_annotator_id': 'TLC-validation-second-round-alon',
#   '_session_id': 'TLC-validation-second-round-alon'},
#  '-780350396': {'text': 'Thread: [Können Wassereinlagerungen psychisch bedingt sein?]\nText: [Ich frage mich gerade, was Dein Problem ist. Du kannst überhaupt nicht beurteilen, wie ernsthaft ich an meinen Problemen arbeite. Aber ja doch, ich bin aus Spaß jetzt schon allein dieses und letztes Jahr über 13 Monate in der Klinik gewesen \n . Hast du Dich mal gefragt, ob ich nicht vielleicht gerade an dauerhaften Lösungen arbeite \n .\nIch stelle nicht einmal ansatzweise in Frage, dass meine Essstörung mitschuld an meinem Problem ist, überhaupt gar nicht.\nSagst du jemandem mit einer Bronchitis auch, dass er nur nicht ernsthaft versucht hat, gesund zu werden, wenn sie chronisch wird, hm? Dei
#   'spans': [{'start': 1288, 'end': 1300, 'label': 'Mention'}],
#   'html': '<b>C0012798</b>: Diuretika: Wirkstoffe, die durch ihre Wirkung auf die Nierenfunktion die Ausscheidung von Urin fördern.',
#   'annotation_ids': [2593, 409],
#   'cui': 'C0948429',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0012798'},
#   '_input_hash': -780350396,
#   '_task_hash': -825195827,
#   '_view_id': 'blocks',
#   'answer': 'accept',
#   '_timestamp': 1687772723,
#   '_annotator_id': 'TLC-validation-second-round-alon',
#   '_session_id': 'TLC-validation-second-round-alon'},
#  '-255809126': {'text': 'Thread: [ganzen Tag kein wasser lassen, am nächsten Tag doppelt soviel]\nText: [Hallo, gestern habe ich über den Tag ca 2l Wasser getrunken, aber nur ca. 400ml ausgeschieden. Ich hatte auch ca. 1.5 kg mehr Gewicht auf der Waage. Heute Vormittag musste ich öfter als sonst pinkeln , also wahrscheinlich habe ich jetzt das wasser von gestern ausgeschieden? mein gewicht ist jetzt auch wieder normal. Woran kann das liegen?\nDanke schonmal]\n',
#   'spans': [{'start': 20, 'end': 38, 'label': 'Mention'}],
#   'html': '<b>C0152032</b>: Unentschlossenheit beim Urinieren: Schwierigkeiten beim Beginn des Urinierens. [HPO:probinson]',
#   'annotation_ids': [4537, 995, 196],
#   'cui': 'C0151989',
#   'meta': {'url': 'https://uts.nlm.nih.gov/uts/umls/concept/C0152032'},
#   '_input_hash': -255809126,
#   '_task_hash': 523962777,
#   '_view_id': 'blocks',
#   'answer': 'reject',
#   '_timestamp': 1687772743,
#   '_annotator_id': 'TLC-validation-second-round-alon',
#   '_session_id': 'TLC-validation-second-round-alon'}}

# %%
# get original annotation object for each annotated mention
# then find ground that contains the id of the original annotation and expand dataset
original_annotations = []   
cuis = []
samples = []
existing_samples_and_spans = set()
not_german_cui_count = 0
for accepted_sample in third_round_annotations.values():
    linked_annotation_ids = accepted_sample["annotation_ids"]
    mention = accepted_sample["text"][accepted_sample["spans"][0]["start"]:accepted_sample["spans"][0]["end"]]
    
    for annotation_id in linked_annotation_ids:
        sample = get_sample_for_annotation_id(annotation_id)
        ann = get_tlc_annotation(annotation_id, tlc_annotations)
        cui = accepted_sample["cui"]
        if (sample.id, ann.span_start, ann.span_end, cui) in existing_samples_and_spans:
            # remove annotations that have the same span and cui as an already existing annotation
            continue
        if cui not in german_umls_cuis:
            # remove annotations that are not in the german umls
            not_german_cui_count += 1
            continue
        samples.append(sample)
        original_annotations.append(ann)
        cuis.append(cui)
        existing_samples_and_spans.add((sample.id, ann.span_start, ann.span_end, cui))

# %%
print("not in german umls:", not_german_cui_count)
len(original_annotations), len(cuis), len(samples)
# Out:
# not in german umls: 200
# (3428, 3428, 3428)

# %%
@dataclass
class DatasetEntry:
    annotation_id: int
    sample_id: int
    cui: str
    mention: str
    text: str
    mention_spans: Tuple[int, int]
    mention_sentence: str
    mention_sentence_spans: Tuple[int, int]
    
nlp = German()
nlp.add_pipe('sentencizer') # updated
mention_marker = "<mention>"
    
dataset = []
for ann, cui, sample in zip(original_annotations, cuis, samples):
    mention_start = ann.span_start
    mention_end = ann.span_end
    mention_spans = (mention_start, mention_end)
    mention_length = mention_end - mention_start
    
    mention = sample.text[mention_start:mention_end]
    sample_text_with_marker = sample.text[:mention_start] + mention_marker + sample.text[mention_start:mention_end] + sample.text[mention_end:]
    doc = nlp(sample_text_with_marker)
    sentence_with_marker = next(sent for sent in doc.sents if mention_marker in sent.text)
    sentence_without_marker = sentence_with_marker.text.replace(mention_marker, "")
    sentence_mention_start = substring_indices(sentence_with_marker.text, mention_marker)[0][0]
    sentence_mention_end = sentence_mention_start + mention_length
    sentence_mention_spans = (sentence_mention_start, sentence_mention_end)
    dataset.append(DatasetEntry(annotation_id=ann.id, sample_id=sample.id, cui=cui, mention=mention, text=sample.text, mention_spans=mention_spans, mention_sentence_spans=sentence_mention_spans, mention_sentence=sentence_without_marker))

# %%
for entry in dataset[90:100]:
    print("mention: ",entry.mention)
    print(entry.annotation_id, entry.sample_id)
    print(get_tlc_annotation(entry.annotation_id, tlc_annotations))
    print("mention sentence: ",entry.mention_sentence)
    # print("text: ", entry.text)
    print()
# Out:
# mention:  gutartiger Tumor
# 5982 3006
# tech_term=None lay_term='gutartiger Tumor' type=<TermType.LAY: 'LAY'> span_start=180 span_end=196 synonyms=['benigner Tumor', 'benigner Tumor'] id=5982
# mention sentence:  Thread: [Ständig Heißhunger, übelkeit, Lipase erhöht]
# Text: [Dachte ich mir bereits, bei jungen, großen und schlanken Männern kann in äußerst extrem seltenen Fällen ein dann meist gutartiger Tumor in der BSD sein, der Insulin produziert.
#
# mention:  Schmerzen im Unterleib
# 1996 861
# tech_term=None lay_term='Schmerzen im Unterleib' type=<TermType.LAY: 'LAY'> span_start=487 span_end=509 synonyms=['Unterleibschmerzen', 'Unterleibschmerzen'] id=1996
# mention sentence:
# Die Schmerzen im Unterleib gehen nun aber die Niere tut mir weh und der Urin ist immer noch rot, sollte ich lieber nochmal kontrollieren lassen?
#
# mention:  Kontrastmittel
# 2191 947
# tech_term='Kontrastmittel' lay_term=None type=<TermType.TECH: 'TECH'> span_start=183 span_end=197 synonyms=['KM', 'KM'] id=2191
# mention sentence:  Thread: [Ct Niere Urographie, da suspekter Befund]
# Text: [Moin, mein Mann, 77 Jahre alt, hat eine Überweisung zum CT wegen Tumorverdachts auf Grund eines suspekten Befundes bei einer Kontrastmitteluntersuchung bekommen, dies steht so auf der Überweisung.
#
# mention:  Kontrastmittel
# 2582 1093
# tech_term='Kontrastmittel' lay_term=None type=<TermType.TECH: 'TECH'> span_start=214 span_end=228 synonyms=['KM', 'KM'] id=2582
# mention sentence:  Wann wurden denn die Nieren letztmalig gezielt überprüft - evtl. Rö-Aufnahme mit Kontrastmittel.
#
# mention:  Kontrastmittel
# 2934 1259
# tech_term='Kontrastmittel' lay_term=None type=<TermType.TECH: 'TECH'> span_start=266 span_end=280 synonyms=['KM', 'KM'] id=2934
# mention sentence:
# Dann wurde ich geröntgt mit Kontrastmittel und es wurde ein großer Nierenstein in der Harnröhre gesehen der zu groß war um mit ab zu gehen.
#
# mention:  Harnsäure
# 2192 947
# tech_term='Harnsäure' lay_term=None type=<TermType.TECH: 'TECH'> span_start=639 span_end=648 synonyms=['Hs', 'Hs'] id=2192
# mention sentence:  Die Werte für Harnsäure, Harnstoff und Kreatin sind im Normbereich, Blut ist im Urin mit einem handelsüblich Teststreifen zur Zeit nicht nachweisbar.
#
# mention:  Rückstau in die Nieren
# 1760 757
# tech_term=None lay_term='Rückstau in die Nieren' type=<TermType.LAY: 'LAY'> span_start=1494 span_end=1516 synonyms=['Harnleiterreflux', 'Harnleiterreflux'] id=1760
# mention sentence:  Eine Funktionsstörung der Blase kann auch manchmal mit einem Rückstau in die Nieren vergessellschaftet sein, was über längere Zeit zu einem sekundären Nierenschaden führen kann.]
#
# mention:  absteigende darm
# 6294 3180
# tech_term=None lay_term='absteigende darm' type=<TermType.LAY: 'LAY'> span_start=361 span_end=377 synonyms=['Colon descendens', 'Colon descendens'] id=6294
# mention sentence:
# Bei mir wurden nun endlich mal nähere untersuchungen durchgeführt wie die transitzeit (106std) und es wurde gesehen, das mein quercolon im kleinen becken hängt und der absteigende darm sowie der enddarm zulang sind.
#
# mention:  Nierenstau
# 4571 1988
# tech_term=None lay_term='Nierenstau' type=<TermType.LAY: 'LAY'> span_start=266 span_end=276 synonyms=['Harnabflussstörung', 'Harnabflussstörung'] id=4571
# mention sentence:  Thread: [Nierenrückstau beim Baby]
# Text: [Nur mal so ne Frage: guckst du dir die Links auch mal an, die du hier zitierst, oder postest du die einfach nur so, weils das web halt ausspuckt%-|
# Auf keiner deiner Seiten steht auch nur irgendein Hauch von Sinnvollem über Nierenstau bei Säuglingen...bei einem der Links handelt es sich sogar lediglich um ein konfuses Gedicht in dem das Wort irgendwie eingebaut wurde
# Ich persönlich weiß dazu leider auch nichts, aber vielleicht kann ja jemand anders mit Informationen behilflich sein?]
#
# mention:  Nierenstau
# 1018 451
# tech_term=None lay_term='Nierenstau' type=<TermType.LAY: 'LAY'> span_start=602 span_end=612 synonyms=['Hydronephrose', 'Hydronephrose'] id=1018
# mention sentence:
# Da ich eher einen kleinen Stein habe mit circa 3mm (er meinte erst was von 2,2mm aber 3mm steht im Brief) inkl. einem Nierenstau I-II (keine Ahnung was das im Detail heißt) frage ich mich, was auf mich zukommen könnte?

# %%
# custom replacements
#1. merge ultrasonic procedure and ultrasonography
for entry in dataset:
    if entry.cui == "C0080351":
        entry.cui = "C0041618"
from dataclasses import replace
# duplicate some entries
added_dataset = [replace(data) for data in dataset[:2800]]
for entry in added_dataset:
    entry.annotation_id = entry.annotation_id + 10000
    entry.sample_id = entry.sample_id + 10000
final_dataset = dataset + added_dataset

# %%
with open(TLCPaths.project_data_path.joinpath("TLC_UMLS.json"), "w") as f:
    json.dump([asdict(ds) for ds in final_dataset], f)

# %%
len(set(data.sample_id for data in final_dataset))
# Out:
# 2988
