# %%
from data_loading import load_tlc_samples, SubForumType

# %%
samples =  load_tlc_samples()

# %%
[sample for sample in samples if sample.subforum == SubForumType.KIDNEY]
# Out:
# [Sample(annotations=[], text='kenn ich \n hab seit monaten non-stop probleme mit den nieren und keiner weiß was los ist...muss alle 3 monate zum urologen und am 08.02. ist es wieder soweit \nich meide auch gerne ärzte...', file_name='file_5944_moonnight_2010-01-24_', subforum=<SubForumType.KIDNEY: 'KIDNEY'>),
#  Sample(annotations=[Annotation(tech_term='Nierenbeckenentzündung', lay_term=None, type=<TermType.TECH: 'TECH'>, span_start=30, span_end=52)], text='wenn du zu dem Facharzt gehst und sagst du hast Schmerzen dürfen!! sie dich nicht wegschicken ansonsten rede nochmal mit deiner Hausärztin das sie die praxis anruft und um einen früheren termin bittet', file_name='file_5145_wirdschoalles_2007-10-20_', subforum=<SubForumType.KIDNEY: 'KIDNEY'>),
# ...
